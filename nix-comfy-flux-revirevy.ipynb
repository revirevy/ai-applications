# %%
import os,subprocess,time

# %%
# %pip install -U uv -q

# %% [raw]
# import os
# from IPython.display import FileLink
# os.chdir("/kaggle/working")
#
# FileLink('output_18112024_1959.zip.zip')

# %%
import os
import zipfile
from datetime import datetime

def zip_folder(folder_path, zip_path):
    with zipfile.ZipFile(zip_path, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for root, _, files in os.walk(folder_path):
            for file in files:
                file_path = os.path.join(root, file)
                arcname = os.path.relpath(file_path, folder_path)
                zipf.write(file_path, arcname)

# Example usage
folder_to_zip = '/kaggle/working/ComfyUI/output'
output_zip = f'/kaggle/working/output_{datetime.now():%d%m%Y_%H%M}.zip'
# zip_folder(folder_to_zip, output_zip)

import shutil
shutil.make_archive(output_zip, 'zip', folder_to_zip)


# Example usage
folder_to_zip = '/kaggle/working/ComfyUI/output'
output_zip = f'/kaggle/working/output_{datetime.now():%d%m%Y_%H%M}.zip'
# zip_folder(folder_to_zip, output_zip)

import shutil
x_old = '/kaggle/working/old_output'
os.makedirs(x_old,exist_ok=True)
if os.path.exists(folder_to_zip):
    for x in os.listdir(folder_to_zip):
        try:
            shutil.move(folder_to_zip +'/' + x, x_old)
        except:
            print("Fichier deja existant??")
# Out:
# INFO: InsightFace detection resolution lowered to (512, 512).
# Requested to load SDXL
# Requested to load ControlNet
# Requested to load ControlNet
# Loading 3 new models
# loaded completely 9.5367431640625e+25 4897.0483474731445 True
# loaded completely 0.0 2396.797637939453 True
# loaded completely 0.0 2386.120147705078 True
#   0%|          | 0/6 [00:00<?, ?it/s]
# WAS Node Suite: Image file saved to: /kaggle/working/ComfyUI/output/InstantID 2024-11-20-16-27-41_0001.jpeg
# WAS Node Suite: Image file saved to: /kaggle/working/ComfyUI/output/InstantID 2024-11-20-16-27-41_0002.jpeg
# WAS Node Suite: Image file saved to: /kaggle/working/ComfyUI/output/InstantID 2024-11-20-16-27-41_0003.jpeg
# WAS Node Suite: Image file saved to: /kaggle/working/ComfyUI/output/InstantID 2024-11-20-16-27-41_0004.jpeg
# HTTP Request: POST https://upload.uploadcare.com/base/ "HTTP/1.1 200 OK"
# HTTP Request: POST https://upload.uploadcare.com/base/ "HTTP/1.1 200 OK"
# HTTP Request: POST https://upload.uploadcare.com/base/ "HTTP/1.1 200 OK"
# HTTP Request: POST https://upload.uploadcare.com/base/ "HTTP/1.1 200 OK"
#  17%|█▋        | 1/6 [00:11<00:58, 11.74s/it]
# >> JOINING PRIMITIVE ' input2 ' INTO BATCH!
#
# >> LOOP [ 101 ] CLOSE
#
# >> LOOP [ 101 ] ITERATION: 2
# VARS= {'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 2, 'finished': False, 'last_id': '100.0.0.R.0.0.100.0.0.101', 'data': 0, 'aux': ('https://ucarecdn.com/5f93b72a-5854-48f4-b1a6-ce92d40d400e/', 'https://ucarecdn.com/275c29a3-2dce-4d36-8f0d-00844c0946a2/'), 'index_override': 2, 'original_id': '101', 'unique_id': '100.0.0.R.0.0.100.0.0.101'}
#
# >> DATA MONITOR [ 100 ]
# TEXT:  %aux%['index']
# PASSTHROUGH:  <class 'NoneType'> None
# AUX INPUTS:  [{'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 2, 'finished': False, 'last_id': '100.0.0.R.0.0.100.0.0.101', 'data': 0, 'aux': ('https://ucarecdn.com/5f93b72a-5854-48f4-b1a6-ce92d40d400e/', 'https://ucarecdn.com/275c29a3-2dce-4d36-8f0d-00844c0946a2/'), 'index_override': 2, 'original_id': '101', 'unique_id': '100.0.0.R.0.0.100.0.0.101', 'condition_open': True}, None, None, None, None]
# PREV: {'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 2, 'finished': False, 'last_id': '100.0.0.R.0.0.100.0.0.101', 'data': 0, 'aux': ('https://ucarecdn.com/33d859dc-cefe-46e8-9eba-23faa729cd07/', 'https://ucarecdn.com/4e2f270f-9753-4361-bd64-f59d4cf2c4fb/'), 'index_override': 2, 'original_id': '101', 'unique_id': '100.0.0.R.0.0.100.0.0.101', 'condition_open': True}['index']
# OUTPUT TYPE:  FORMULA
# REPLACING '%aux%' in '%aux%['index']' with '{'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 2, 'finished': False, 'last_id': '100.0.0.R.0.0.100.0.0.101', 'data': 0, 'aux': ('https://ucarecdn.com/5f93b72a-5854-48f4-b1a6-ce92d40d400e/', 'https://ucarecdn.com/275c29a3-2dce-4d36-8f0d-00844c0946a2/'), 'index_override': 2, 'original_id': '101', 'unique_id': '100.0.0.R.0.0.100.0.0.101', 'condition_open': True}'!
# >> PROCESSED TEXT AFTER VARIABLE REPLACEMENT: '{'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 2, 'finished': False, 'last_id': '100.0.0.R.0.0.100.0.0.101', 'data': 0, 'aux': ('https://ucarecdn.com/5f93b72a-5854-48f4-b1a6-ce92d40d400e/', 'https://ucarecdn.com/275c29a3-2dce-4d36-8f0d-00844c0946a2/'), 'index_override': 2, 'original_id': '101', 'unique_id': '100.0.0.R.0.0.100.0.0.101', 'condition_open': True}['index']'
# RETURN [TEXT]: 2

# %%
def install_this(xthe_url):
    import os
    print("install ",xthe_url)
    if not os.path.exists("/kaggle/working/ComfyUI/custom_nodes/"):
        os.makedirs("/kaggle/working/ComfyUI/custom_nodes/")
    
    # %cd /kaggle/working/ComfyUI/custom_nodes
    xfolder =  xthe_url.split('/')[-1].replace('.git','')
    if not os.path.exists("/kaggle/working/ComfyUI/custom_nodes/" + xfolder):
        get_ipython().system(f'git clone {xthe_url}')
    
    print(f"{xfolder=}")
    # %cd /kaggle/working/ComfyUI/custom_nodes/$xfolder
    get_ipython().system('git pull --all')
    if os.path.exists("requirements.txt"):
        # !uv pip install --system -r requirements.txt --quiet  #-U --upgrade-strategy only-if-needed
#     else :
#         %pip install --quiet
    print("DONE install ",xthe_url)

# %%
update = True

from os import path
import os
# if not path.exists("/kaggle/working/ComfyUI/"):
# %cd /kaggle/working
if not path.exists("/kaggle/working/ComfyUI/"):
    get_ipython().system(f'git clone https://github.com/comfyanonymous/ComfyUI.git')
# %cd ComfyUI
if update:
    get_ipython().system('git pull --all')
# !uv pip install --system  -r requirements.txt --quiet

# %%
import os
if not os.path.exists("/kaggle/working/ComfyUI/models/LLM"):
    os.makedirs("/kaggle/working/ComfyUI/models/LLM")
if not os.path.exists("/kaggle/working/ComfyUI/models/pulid"):
    os.makedirs("/kaggle/working/ComfyUI/models/pulid")
if not os.path.exists("/kaggle/working/ComfyUI/models/clip_vision"):
    os.makedirs("/kaggle/working/ComfyUI/models/clip_vision")    
if not os.path.exists("/kaggle/working/ComfyUI/models/xlabs/contronets"):
    os.makedirs("/kaggle/working/ComfyUI/models/xlabs/contronets/")

# %%
install_this("https://github.com/comfyanonymous/ComfyUI_bitsandbytes_NF4")
# Was node
install_this('https://github.com/WASasquatch/was-node-suite-comfyui')
# Rgthree
install_this("https://github.com/rgthree/rgthree-comfy")
# REactor
install_this("https://github.com/Gourieff/comfyui-reactor-node")
# Comfyui noise
install_this("https://github.com/BlenderNeko/ComfyUI_Noise")
# Comfyui impact
install_this("https://github.com/ltdrdata/ComfyUI-Impact-Pack")
# pythongossss
install_this("https://github.com/pythongosssss/ComfyUI-Custom-Scripts")
# Comfyui easy use
install_this("https://github.com/yolain/ComfyUI-Easy-Use")
# KJNODES
install_this("https://github.com/kijai/ComfyUI-KJNodes") 
# Flux comfyui
install_this("https://github.com/kijai/ComfyUI-Florence2") 
install_this("https://github.com/XLabs-AI/x-flux-comfyui") 
install_this("https://github.com/crystian/ComfyUI-Crystools") 
install_this("https://github.com/city96/ComfyUI-GGUF")

install_this("https://github.com/cubiq/PuLID_ComfyUI")
install_this("https://github.com/cubiq/ComfyUI_InstantID")
install_this("https://github.com/cubiq/ComfyUI_IPAdapter_plus")
install_this("https://github.com/revirevy/Comfyui_saveimage_imgbb")

# install_this("https://github.com/ltdrdata/ComfyUI-Manager")

# %%
for x in """https://github.com/comfyanonymous/ComfyUI_experiments
    https://github.com/Fannovel16/comfyui_controlnet_aux
        https://github.com/jamesWalker55/comfyui-various
            https://github.com/kijai/ComfyUI-SUPIR
                https://github.com/klinter007/klinter_nodes
    https://github.com/holchan/ComfyUI-ModelDownloader
        https://github.com/KoreTeknology/ComfyUI-Universal-Styler
            https://github.com/marduk191/ComfyUI-Fluxpromptenhancer
                https://github.com/fairy-root/Flux-Prompt-Generator
                    https://github.com/VykosX/ControlFlowUtils
                        https://github.com/godmt/ComfyUI-List-Utils""".split("\n"):
    install_this(x.strip())
print("="*50,'ALL DONE','='*50,sep='\n')

# %%
install_this("https://github.com/ltdrdata/ComfyUI-Manager")

# %%
# !ln -s  /kaggle/input/clip-gmp-vit-l-14/tensorflow2/default/1/model.safetensors    /kaggle/working/ComfyUI/models/clip/CLIP_gmp_VIT_L_14.safetensors

# !ls -trahl  /kaggle/working/ComfyUI/models/vae

# !ls -trahl  /kaggle/working/ComfyUI/models/clip/
# !ls -ltrah /kaggle/input/

# !ln -s /kaggle/input/t5xxl_fp16.safetensors/tensorflow2/default/1/t5xxl_fp16.safetensors   /kaggle/working/ComfyUI/models/clip/t5xxl_fp16.safetensors
# !ln -s  /kaggle/input/flux-vae-safetensors/pytorch/default/1/ae.safetensors    /kaggle/working/ComfyUI/models/vae/FLuX_ae.safetensors

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/FLUX.1-dev/resolve/main/flux1-dev-fp8.safetensors -d /kaggle/working/ComfyUI/models/unet -o flux1-dev-fp8.safetensors
# !ln -s /kaggle/input/flux/pytorch/flux.1-dev/1/flux1-dev.safetensors /kaggle/working/ComfyUI/models/unet/flux1-dev.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/FLUX.1-dev/resolve/main/ae.sft -d /kaggle/working/ComfyUI/models/vae -o ae.sft
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/FLUX.1-dev/resolve/main/clip_l.safetensors -d /kaggle/working/ComfyUI/models/clip -o clip_l.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/FLUX.1-dev/resolve/main/t5xxl_fp8_e4m3fn.safetensors -d /kaggle/working/ComfyUI/models/clip -o t5xxl_fp8_e4m3fn.safetensors
# !ln -s /kaggle/input/clip/pytorch/t5xxl_fp8_e4m3fn/1/t5xxl_fp8_e4m3fn.safetensors /kaggle/working/ComfyUI/models/clip/t5xxl_fp8_e4m3fn.safetensors
# !ln -s  /kaggle/input/t5-fine-tuned/transformers/t5-2/1/model.safetensors    /kaggle/working/ComfyUI/models/clip/t5-2-model.safetensors
# !ln -s /kaggle/input/t5xxl_fp16/tensorflow2/default/1/t5xxl_fp16.safetensors   /kaggle/working/ComfyUI/models/clip/t5xxl_fp16.safetensors

# !ln -s  /kaggle/input/flan-t5/pytorch/large/3/model.safetensors             /kaggle/working/ComfyUI/models/clip/flan-t5-large-model.safetensors
# !ln -s  /kaggle/input/clip-gpt2_t5/pytorch/1/1/net-cross-description.pt    /kaggle/working/ComfyUI/models/clip/net-cross-description.pt

# !ln -s /kaggle/input/florence2/transformers/default/1/Florence2_model_3/model.safetensors /kaggle/working/ComfyUI/models/LLM/Florence_model_3.safetensors
# !ln -s /kaggle/input/florence2/transformers/default/1/Florence2_model_2/model.safetensors /kaggle/working/ComfyUI/models/LLM/Florence_model_2.safetensors
# !ln -s /kaggle/input/controlnet/pytorch/flux-canny-controlnet/1/flux-canny-controlnet-v3.safetensors  /kaggle/working/ComfyUI/models/xlabs/contronets/flux-canny-controlnet-v3.safetensors
# !ln -s /kaggle/input/controlnet/pytorch/flux-depth-controlnet/1/flux-depth-controlnet-v3.safetensors  /kaggle/working/ComfyUI/models/xlabs/contronets/flux-depth-controlnet-v3.safetensors
# !ln -s /kaggle/input/stable-diffusion-xl/pytorch/base-1-0/1/sd_xl_base_1.0_0.9vae.safetensors /kaggle/working/ComfyUI/models/checkpoints/sd_xl_base_1.0_0.9vae.safetensors

# !ln -s /kaggle/input/realvisxl-v50/pytorch/default/1/realvisxl-v50.safetensors  /kaggle/working/ComfyUI/models/checkpoints/realvisxl-v50.safetensors
# !ln -s /kaggle/input/realvisxl-v50/pytorch/default/2/SG161222_RealVisXL_V5_0_Lightning.safetensors  /kaggle/working/ComfyUI/models/checkpoints/SG161222_RealVisXL_V5_0_Lightning.safetensors
# !ln -s /kaggle/input/stable-diffusion-xl/pytorch/base-1-0/1/sd_xl_base_1.0.safetensors /kaggle/working/ComfyUI/models/checkpoints/sd_xl_base_1.0.safetensors
# !ln -s /kaggle/input/stoiqo-new-reality-flux-sd_f1d-pre-alpha/transformers/default/1/STOIQONewrealityFLUXSD_F1DPreAlpha.safetensors /kaggle/working/ComfyUI/models/checkpoints/STOIQONewrealityFLUXSD_F1DPreAlpha.safetensors
# !ln -s /kaggle/input/flux1devnf46stepsnsfw/pytorch/default/1/flux1DevNF46StepsNSFW_fluxdevFP86Steps.safetensors /kaggle/working/ComfyUI/models/checkpoints/flux1DevNF46StepsNSFW_fluxdevFP86Steps.safetensors
# !ln -s /kaggle/input/8stepscrearthyperfluxdevbnb_v24hyperdevfp8unet_/pytorch/default/1/8StepsCreartHyperFluxDevBnb_v24HyperDevFp8Unet.safetensors  /kaggle/working/ComfyUI/models/unet/8StepsCreartHyperFluxDevBnb_v24HyperDevFp8Unet.safetensors
# !ln -s /kaggle/input/creart-hyper-flux-dev-gguf-q4_0/gguf/default/1/CreArt-Hyper-Flux-Dev-gguf-q4_0.gguf /kaggle/working/ComfyUI/models/unet/CreArt-Hyper-Flux-Dev-gguf-q4_0.gguf
# !ln -s /kaggle/input/unet/gguf/flux1-dev-q4_k_s/1/flux1-dev-Q4_K_S.gguf /kaggle/working/ComfyUI/models/unet/flux1-dev-Q4_K_S.gguf
# !ln -s /kaggle/input/aldebodobasexl_v3mini/tensorflow2/default/1/albedobaseXL_v3Mini.safetensors /kaggle/working/ComfyUI/models/checkpoints/albedobaseXL_v3Mini.safetensors
# /kaggle/input/aldebodobasexl_v3mini/tensorflow2/default/1/albedobaseXL_v3Mini.safetensors



# !ln -s /kaggle/input/alimama-flux-turbo-lora/pytorch/default/1/diffusion_pytorch_model.safetensors /kaggle/working/ComfyUI/models/loras/alimama-flux-turbo-lora.safetensors

# !ln -s /kaggle/input/fluxartfusion4steps_v12/pytorch/default/1/fluxArtfusion4Steps_v12.safetensors  /kaggle/working/ComfyUI/models/checkpoints/fluxArtfusion4Steps_v12.safetensors
# !ln -s /kaggle/input/fluxartfusion4steps_v12/pytorch/default/1/fluxArtfusion4Steps_v12.safetensors


for x in os.listdir("/kaggle/input/flux_loras/pytorch/default/1"):
    print(x)
    # !ln -s "/kaggle/input/flux_loras/pytorch/default/1/$x" "/kaggle/working/ComfyUI/models/loras/$x"
# Out:
#  72%|███████▏  | 13/18 [01:08<00:23,  4.72s/it]
# ln: failed to create symbolic link '/kaggle/working/ComfyUI/models/clip/CLIP_gmp_VIT_L_14.safetensors': File exists
# INFO: InsightFace detection resolution lowered to (512, 512).
# ln: failed to create symbolic link '/kaggle/working/ComfyUI/models/clip/t5xxl_fp16.safetensors': File exists
# ln: failed to create symbolic link '/kaggle/working/ComfyUI/models/vae/FLuX_ae.safetensors': File exists
# Requested to load SDXL
# Requested to load ControlNet
# Requested to load ControlNet
# Loading 3 new models
# loaded completely 9.5367431640625e+25 4897.0483474731445 True
# loaded completely 0.0 2396.797637939453 True
# loaded completely 0.0 2386.120147705078 True
#   0%|          | 0/18 [00:00<?, ?it/s]
# ln: failed to create symbolic link '/kaggle/working/ComfyUI/models/clip/t5xxl_fp8_e4m3fn.safetensors': File exists
#  78%|███████▊  | 14/18 [01:13<00:18,  4.64s/it]
# ln: failed to create symbolic link '/kaggle/working/ComfyUI/models/LLM/Florence_model_3.safetensors': File exists
# ln: failed to create symbolic link '/kaggle/working/ComfyUI/models/LLM/Florence_model_2.safetensors': File exists
# ln: failed to create symbolic link '/kaggle/working/ComfyUI/models/xlabs/contronets/flux-canny-controlnet-v3.safetensors': File exists
#  83%|████████▎ | 15/18 [01:17<00:13,  4.58s/it]
# ln: failed to create symbolic link '/kaggle/working/ComfyUI/models/xlabs/contronets/flux-depth-controlnet-v3.safetensors': File exists
#   6%|▌         | 1/18 [00:06<01:54,  6.71s/it]
# ln: failed to create symbolic link '/kaggle/working/ComfyUI/models/checkpoints/realvisxl-v50.safetensors': File exists
# ln: failed to create symbolic link '/kaggle/working/ComfyUI/models/checkpoints/flux1DevNF46StepsNSFW_fluxdevFP86Steps.safetensors': File exists
#  89%|████████▉ | 16/18 [01:22<00:09,  4.53s/it]
# ln: failed to create symbolic link '/kaggle/working/ComfyUI/models/unet/8StepsCreartHyperFluxDevBnb_v24HyperDevFp8Unet.safetensors': File exists
# ln: failed to create symbolic link '/kaggle/working/ComfyUI/models/unet/CreArt-Hyper-Flux-Dev-gguf-q4_0.gguf': File exists
# ln: failed to create symbolic link '/kaggle/working/ComfyUI/models/unet/flux1-dev-Q4_K_S.gguf': File exists
#  11%|█         | 2/18 [00:13<01:47,  6.74s/it]
# ln: failed to create symbolic link '/kaggle/working/ComfyUI/models/checkpoints/albedobaseXL_v3Mini.safetensors': File exists
#  94%|█████████▍| 17/18 [01:26<00:04,  4.49s/it]
# ln: failed to create symbolic link '/kaggle/working/ComfyUI/models/loras/alimama-flux-turbo-lora.safetensors': File exists
# ln: failed to create symbolic link '/kaggle/working/ComfyUI/models/checkpoints/fluxArtfusion4Steps_v12.safetensors': File exists
# Text_Style_Autonomy-000005.safetensors
# ln: failed to create symbolic link '/kaggle/working/ComfyUI/models/loras/Text_Style_Autonomy-000005.safetensors': File exists
# perfect text title style v2.safetensors
# 100%|██████████| 18/18 [01:30<00:00,  5.05s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# ln: failed to create symbolic link '/kaggle/working/ComfyUI/models/loras/perfect text title style v2.safetensors': File exists
# aidmaImageUpgrader-FLUX-V0.2.safetensors
# loaded completely 0.0 319.11416244506836 True
# ln: failed to create symbolic link '/kaggle/working/ComfyUI/models/loras/aidmaImageUpgrader-FLUX-V0.2.safetensors': File exists
# I-Type-You-Listen.safetensors
#  17%|█▋        | 3/18 [00:20<01:42,  6.81s/it]
# ln: failed to create symbolic link '/kaggle/working/ComfyUI/models/loras/I-Type-You-Listen.safetensors': File exists
# ideogram1024-000006.safetensors
# ln: failed to create symbolic link '/kaggle/working/ComfyUI/models/loras/ideogram1024-000006.safetensors': File exists
# Smash_Bros_Character_Reveal_FLUX-000021.safetensors
# ln: failed to create symbolic link '/kaggle/working/ComfyUI/models/loras/Smash_Bros_Character_Reveal_FLUX-000021.safetensors': File exists
# Textimprover-FLUX-V0.4.safetensors
# ln: failed to create symbolic link '/kaggle/working/ComfyUI/models/loras/Textimprover-FLUX-V0.4.safetensors': File exists

# %%
#     /kaggle/input/t5_xxl_gguf_models/pytorch/default/1/t5-v1_1-xxl-encoder-Q8_0.gguf
#     /kaggle/input/t5_xxl_gguf_models/pytorch/default/1/t5-v1_1-xxl-encoder-Q8_0.gguf
for x in os.listdir("/kaggle/input/t5_xxl_gguf_models/pytorch/default/1/"):
    print(x)
    # !ln -s "/kaggle/input/t5_xxl_gguf_models/pytorch/default/1/$x" "/kaggle/working/ComfyUI/models/clip/$x"

# %%
#     /kaggle/input/t5_xxl_gguf_models/pytorch/default/1/t5-v1_1-xxl-encoder-Q8_0.gguf
#     /kaggle/input/t5_xxl_gguf_models/pytorch/default/1/t5-v1_1-xxl-encoder-Q8_0.gguf
# /kaggle/input/sdxl_controlnets/pytorch/default/2
os.makedirs('/kaggle/working/ComfyUI/models/ipadapter',exist_ok=True)
os.makedirs('/kaggle/working/ComfyUI/models/controlnet',exist_ok=True)
for x in os.listdir("/kaggle/input/sdxl_controlnets/pytorch/default/3/"):
    # !rm /kaggle/working/ComfyUI/models/controlnet/$x
    print(x)
    # !ln -s "/kaggle/input/sdxl_controlnets/pytorch/default/3/$x" "/kaggle/working/ComfyUI/models/controlnet/$x"
    if 'ip-adapter' in x:
        # !ln -s "/kaggle/input/sdxl_controlnets/pytorch/default/3/$x" "/kaggle/working/ComfyUI/models/ipadapter/$x"

# %%
for x in os.listdir("/kaggle/input/pulid-model/pytorch/default/3/"):
    print(x)
    # !ln -s "/kaggle/input/pulid-model/pytorch/default/3/$x" "/kaggle/working/ComfyUI/models/pulid/$x"


# /kaggle/input/pulid-model/pytorch/default/3/ip-adapter_pulid_sdxl_fp16.safetensors
# !ln -s /kaggle/input/pulid-model/pytorch/default/2/pulid_v1.bin /kaggle/working/ComfyUI/models/pulid/pulid_v1.bin
# !ln -s /kaggle/input/pulid-model/pytorch/default/1/pulid_flux_v0.9.0.safetensors /kaggle/working/ComfyUI/models/pulid/pulid_flux_v0.9.0.safetensors
# !ln -s /kaggle/input/clip-vit/pytorch/h-14-laion2b-s32b-b79k/1/pytorch_model.bin  /kaggle/working/ComfyUI/models/clip_vision/clip_vit_h-14-laion2b-s32b-b79k.bin

# %%
os.makedirs('/kaggle/working/ComfyUI/models/controlnet/instantid',exist_ok=True)
# !ln -s /kaggle/input/instant_id/pytorch/default/2/controlnet_instantid_model.safetensors /kaggle/working/ComfyUI/models/controlnet/instantid/LeInstantID_ControlNet_model.safetensors

# %%
os.makedirs('/kaggle/working/ComfyUI/models/instantid/SDXL',exist_ok=True)
# !ln -s /kaggle/input/instant_id/pytorch/default/2/instantid-ip-adapter.bin /kaggle/working/ComfyUI/models/instantid/InstantID_ip_adapter.bin
# !ln -s /kaggle/input/instant_id/pytorch/default/2/instantid-ip-adapter.bin /kaggle/working/ComfyUI/models/instantid/ip_adapter.bin
# !ln -s /kaggle/input/instant_id/pytorch/default/2/instantid-ip-adapter.bin /kaggle/working/ComfyUI/models/instantid/SDXL/ip-adapter.bin

# %%
for x in os.listdir("/kaggle/input/pulid-model/pytorch/default/3/"):
    print(x)
    # !ln -s "/kaggle/input/pulid-model/pytorch/default/3/$x" "/kaggle/working/ComfyUI/models/pulid/$x"


# /kaggle/input/pulid-model/pytorch/default/3/ip-adapter_pulid_sdxl_fp16.safetensors
# !ln -s /kaggle/input/pulid-model/pytorch/default/2/pulid_v1.bin /kaggle/working/ComfyUI/models/pulid/pulid_v1.bin
# !ln -s /kaggle/input/pulid-model/pytorch/default/1/pulid_flux_v0.9.0.safetensors /kaggle/working/ComfyUI/models/pulid/pulid_flux_v0.9.0.safetensors
# !ln -s /kaggle/input/clip-vit/pytorch/h-14-laion2b-s32b-b79k/1/pytorch_model.bin  /kaggle/working/ComfyUI/models/clip_vision/clip_vit_h-14-laion2b-s32b-b79k.bin

# %%
#     /kaggle/input/t5_xxl_gguf_models/pytorch/default/1/t5-v1_1-xxl-encoder-Q8_0.gguf
#     /kaggle/input/t5_xxl_gguf_models/pytorch/default/1/t5-v1_1-xxl-encoder-Q8_0.gguf
# /kaggle/input/sdxl_controlnets/pytorch/default/2
for x in os.listdir("/kaggle/input/controlnet-package-hsbd10/pytorch/default/4/"):
    print(x)
    # !ln -s "/kaggle/input/controlnet-package-hsbd10/pytorch/default/4/$x" "/kaggle/working/ComfyUI/models/controlnet/$x"

# %%
#     /kaggle/input/t5_xxl_gguf_models/pytorch/default/1/t5-v1_1-xxl-encoder-Q8_0.gguf
#     /kaggle/input/t5_xxl_gguf_models/pytorch/default/1/t5-v1_1-xxl-encoder-Q8_0.gguf
for x in os.listdir("/kaggle/input/t5_xxl_gguf_models/pytorch/default/1/"):
    print(x)
    # !ln -s "/kaggle/input/t5_xxl_gguf_models/pytorch/default/1/$x" "/kaggle/working/ComfyUI/models/clip/$x"

# %%
# %ls -ltrha/kaggle/working/ComfyUI/models/clip/

# %%
# %%writefile /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager/config.ini
# [default]
# preview_method = none
# badge_mode = none
# git_exe =
# channel_url = https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main
# share_option = all
# bypass_ssl = False
# file_logging = True
# default_ui = none
# component_policy = workflow
# double_click_policy = copy-all
# windows_selector_event_loop_policy = False
# model_download_by_agent = True
# downgrade_blacklist =
# security_level = normal-

# %%
# Comfyui impact
install_this("https://github.com/ltdrdata/ComfyUI-Impact-Pack")

# %% [raw]
# !uv pip install insightface onnxruntime-gpu diffusers einops accelerate -q torch torchvision torchsde --system

# %%
# Change directory to ComfyUI
import os, subprocess, time
os.chdir("/kaggle/working/ComfyUI/")

# Launch ComfyUI instances
xP1 = subprocess.Popen(["python", "main.py", "--cuda-device", "0", "--port", "8188","--highvram"])
time.sleep(10)

xP2= subprocess.Popen(["python", "main.py", "--cuda-device", "1", "--port", "8189","--highvram"])
time.sleep(10)
# subprocess.Popen(["./limit_ram.sh","python", "main.py", "--cuda-device", "0", "--port", "8188"])
# subprocess.Popen(["./limit_ram.sh","python", "main.py", "--cuda-device", "1", "--port", "8189"])

# time.sleep(30)

# %%
os.chdir("/kaggle/working/ComfyUI/")
if  not os.path.exists('/kaggle/working/ComfyUI/playit-linux-amd64'):
    # !wget https://github.com/playit-cloud/playit-agent/releases/download/v0.15.26/playit-linux-amd64
# !chmod 777 /kaggle/working/ComfyUI/playit-linux-amd64

# !ls -ltrha play*

# %%
# !wget https://github.com/playit-cloud/playit-agent/releases/download/v0.15.26/playit-linux-amd64 -q
# !chmod +x ./playit-linux-amd64 
# !./playit-linux-amd64  --help

# %%
subprocess.Popen("nohup /kaggle/working/ComfyUI/playit-linux-amd64   >> /kaggle/working/ComfyUI/logs/playit.log 2>&1 & echo 'done' ",bufsize=0,shell=True)

# %%
# !tail -n 20 /kaggle/working/ComfyUI/logs/playit.log

# %%
# !ps fax
# Out:
#     PID TTY      STAT   TIME COMMAND
#      33 ?        Ss     0:28 /opt/bin/nvidia-smi -l 1 --query-gpu=index,utilizat
#       1 ?        Ssl    2:34 /opt/conda/bin/python3.10 /opt/conda/bin/jupyter-no
#      30 ?        Ssl    0:39 /opt/conda/bin/python3.10 -m ipykernel_launcher -f
#     959 ?        SLl  315:41  \_ /opt/conda/bin/python main.py --cuda-device 0 -
#     974 ?        SLl  341:52  \_ /opt/conda/bin/python main.py --cuda-device 1 -
#    1095 ?        Z      0:00  \_ [sh] <defunct>
#    1842 pts/0    Rs+    0:01  \_ ps fax
#      56 ?        Sl     0:27 /opt/conda/bin/python3.10 -m pylsp
#    1831 ?        S      0:00  \_ /opt/conda/bin/python3.10 /opt/conda/lib/python
#    1096 ?        Sl     0:59 /kaggle/working/ComfyUI/playit-linux-amd64
# Requested to load SDXLClipModel
# Loading 1 new model
# loaded completely 0.0 1560.802734375 True
# Requested to load SDXL
# Loading 1 new model
# loaded completely 9.5367431640625e+25 4897.0483474731445 True
# 100%|██████████| 5/5 [00:07<00:00,  1.49s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# loaded completely 0.0 319.11416244506836 True
# INFO: InsightFace detection resolution lowered to (512, 512).
# Requested to load ControlNet
# Requested to load SDXL
# Requested to load ControlNet
# Loading 3 new models
# loaded completely 0.0 2386.120147705078 True
# loaded completely 9.5367431640625e+25 4897.0483474731445 True
# loaded completely 0.0 2396.797637939453 True
# 100%|██████████| 6/6 [00:58<00:00,  9.78s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# loaded completely 0.0 319.11416244506836 True
#  43%|████▎     | 3/7 [00:43<00:57, 14.35s/it]
# WAS Node Suite: Image file saved to: /kaggle/working/ComfyUI/output/InstantID 2024-11-20-16-29-01_0001.jpeg
# WAS Node Suite: Image file saved to: /kaggle/working/ComfyUI/output/InstantID 2024-11-20-16-29-01_0002.jpeg
# WAS Node Suite: Image file saved to: /kaggle/working/ComfyUI/output/InstantID 2024-11-20-16-29-01_0003.jpeg
# WAS Node Suite: Image file saved to: /kaggle/working/ComfyUI/output/InstantID 2024-11-20-16-29-01_0004.jpeg
# HTTP Request: POST https://upload.uploadcare.com/base/ "HTTP/1.1 200 OK"
# HTTP Request: POST https://upload.uploadcare.com/base/ "HTTP/1.1 200 OK"
#  57%|█████▋    | 4/7 [00:55<00:40, 13.45s/it]HTTP Request: POST https://upload.uploadcare.com/base/ "HTTP/1.1 200 OK"
# HTTP Request: POST https://upload.uploadcare.com/base/ "HTTP/1.1 200 OK"
# >> TRIGGERING GARBAGE COLLECTION.
# >> MEMORY CLEANER PROCESS NOT FOUND OR CANNOT BE EXECUTED. ENSURE 'WinMemoryCleaner.exe' IS PRESENT IN COMFYUI ROOT FOLDER.
#
# >> LOOP [ 101 ] CLOSE
#
# >> LOOP [ 101 ] ITERATION: 1
# VARS= {'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 1, 'finished': False, 'last_id': '100.0.0.101', 'data': 0, 'aux': 'https://ucarecdn.com/dd87fb94-59e8-401c-90d7-4c6587cdfb62/', 'index_override': 1, 'original_id': '101', 'unique_id': '100.0.0.101'}
#
# >> DATA MONITOR [ 100 ]
# TEXT:  %aux%['index']
# PASSTHROUGH:  <class 'NoneType'> None
# AUX INPUTS:  [{'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 1, 'finished': False, 'last_id': '100.0.0.101', 'data': 0, 'aux': 'https://ucarecdn.com/dd87fb94-59e8-401c-90d7-4c6587cdfb62/', 'index_override': 1, 'original_id': '101', 'unique_id': '100.0.0.101', 'condition_open': True}, None, None, None, None]
# PREV: {'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 1, 'finished': False, 'last_id': '100.0.0.101', 'data': 0, 'aux': 'https://ucarecdn.com/9cba0503-cd70-416a-b248-9669aa0e9a49/', 'index_override': 1, 'original_id': '101', 'unique_id': '100.0.0.101', 'condition_open': True}['index']
# OUTPUT TYPE:  FORMULA
# REPLACING '%aux%' in '%aux%['index']' with '{'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 1, 'finished': False, 'last_id': '100.0.0.101', 'data': 0, 'aux': 'https://ucarecdn.com/dd87fb94-59e8-401c-90d7-4c6587cdfb62/', 'index_override': 1, 'original_id': '101', 'unique_id': '100.0.0.101', 'condition_open': True}'!
# >> PROCESSED TEXT AFTER VARIABLE REPLACEMENT: '{'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 1, 'finished': False, 'last_id': '100.0.0.101', 'data': 0, 'aux': 'https://ucarecdn.com/dd87fb94-59e8-401c-90d7-4c6587cdfb62/', 'index_override': 1, 'original_id': '101', 'unique_id': '100.0.0.101', 'condition_open': True}['index']'
# RETURN [TEXT]: 1
# Requested to load SDXLClipModel
# Loading 1 new model
# loaded completely 0.0 1560.802734375 True
# Requested to load SDXL
# Loading 1 new model
# loaded completely 0.0 4897.0483474731445 True
# 100%|██████████| 5/5 [00:06<00:00,  1.23s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# loaded completely 0.0 319.11416244506836 True
#  86%|████████▌ | 6/7 [01:15<00:11, 11.68s/it]
# INFO: InsightFace detection resolution lowered to (512, 512).
# Requested to load ControlNet
# Requested to load ControlNet
# Requested to load SDXL
# Loading 3 new models
# loaded completely 0.0 2386.120147705078 True
# loaded completely 0.0 2396.797637939453 True
# loaded completely 9.5367431640625e+25 4897.0483474731445 True
# 100%|██████████| 7/7 [01:21<00:00, 11.60s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# loaded completely 0.0 319.11416244506836 True
#  33%|███▎      | 2/6 [00:23<00:47, 11.89s/it]
# WAS Node Suite: Image file saved to: /kaggle/working/ComfyUI/output/InstantID 2024-11-20-16-30-02_0001.jpeg
# WAS Node Suite: Image file saved to: /kaggle/working/ComfyUI/output/InstantID 2024-11-20-16-30-02_0002.jpeg
# WAS Node Suite: Image file saved to: /kaggle/working/ComfyUI/output/InstantID 2024-11-20-16-30-02_0003.jpeg
# WAS Node Suite: Image file saved to: /kaggle/working/ComfyUI/output/InstantID 2024-11-20-16-30-02_0004.jpeg
# HTTP Request: POST https://upload.uploadcare.com/base/ "HTTP/1.1 200 OK"
#  50%|█████     | 3/6 [00:35<00:35, 11.91s/it]HTTP Request: POST https://upload.uploadcare.com/base/ "HTTP/1.1 200 OK"
# HTTP Request: POST https://upload.uploadcare.com/base/ "HTTP/1.1 200 OK"
# HTTP Request: POST https://upload.uploadcare.com/base/ "HTTP/1.1 200 OK"
# >> JOINING PRIMITIVE ' input2 ' INTO BATCH!
#
# >> LOOP [ 101 ] CLOSE
#
# >> LOOP [ 101 ] ITERATION: 3
# VARS= {'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 3, 'finished': False, 'last_id': '100.0.0.R.0.0.R.0.0.100.0.0.R.0.0.100.0.0.101', 'data': 0, 'aux': ('https://ucarecdn.com/5f93b72a-5854-48f4-b1a6-ce92d40d400e/', 'https://ucarecdn.com/275c29a3-2dce-4d36-8f0d-00844c0946a2/', 'https://ucarecdn.com/e0f61440-2169-4246-8e6b-31d901434243/'), 'index_override': 3, 'original_id': '101', 'unique_id': '100.0.0.R.0.0.R.0.0.100.0.0.R.0.0.100.0.0.101'}
#
# >> DATA MONITOR [ 100 ]
# TEXT:  %aux%['index']
# PASSTHROUGH:  <class 'NoneType'> None
# AUX INPUTS:  [{'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 3, 'finished': False, 'last_id': '100.0.0.R.0.0.R.0.0.100.0.0.R.0.0.100.0.0.101', 'data': 0, 'aux': ('https://ucarecdn.com/5f93b72a-5854-48f4-b1a6-ce92d40d400e/', 'https://ucarecdn.com/275c29a3-2dce-4d36-8f0d-00844c0946a2/', 'https://ucarecdn.com/e0f61440-2169-4246-8e6b-31d901434243/'), 'index_override': 3, 'original_id': '101', 'unique_id': '100.0.0.R.0.0.R.0.0.100.0.0.R.0.0.100.0.0.101', 'condition_open': True}, None, None, None, None]
# PREV: {'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 3, 'finished': False, 'last_id': '100.0.0.R.0.0.R.0.0.100.0.0.R.0.0.100.0.0.101', 'data': 0, 'aux': ('https://ucarecdn.com/33d859dc-cefe-46e8-9eba-23faa729cd07/', 'https://ucarecdn.com/4e2f270f-9753-4361-bd64-f59d4cf2c4fb/', 'https://ucarecdn.com/1df13082-bc56-4cb8-b387-47b7da2e07cc/'), 'index_override': 3, 'original_id': '101', 'unique_id': '100.0.0.R.0.0.R.0.0.100.0.0.R.0.0.100.0.0.101', 'condition_open': True}['index']
# OUTPUT TYPE:  FORMULA
# REPLACING '%aux%' in '%aux%['index']' with '{'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 3, 'finished': False, 'last_id': '100.0.0.R.0.0.R.0.0.100.0.0.R.0.0.100.0.0.101', 'data': 0, 'aux': ('https://ucarecdn.com/5f93b72a-5854-48f4-b1a6-ce92d40d400e/', 'https://ucarecdn.com/275c29a3-2dce-4d36-8f0d-00844c0946a2/', 'https://ucarecdn.com/e0f61440-2169-4246-8e6b-31d901434243/'), 'index_override': 3, 'original_id': '101', 'unique_id': '100.0.0.R.0.0.R.0.0.100.0.0.R.0.0.100.0.0.101', 'condition_open': True}'!
# >> PROCESSED TEXT AFTER VARIABLE REPLACEMENT: '{'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 3, 'finished': False, 'last_id': '100.0.0.R.0.0.R.0.0.100.0.0.R.0.0.100.0.0.101', 'data': 0, 'aux': ('https://ucarecdn.com/5f93b72a-5854-48f4-b1a6-ce92d40d400e/', 'https://ucarecdn.com/275c29a3-2dce-4d36-8f0d-00844c0946a2/', 'https://ucarecdn.com/e0f61440-2169-4246-8e6b-31d901434243/'), 'index_override': 3, 'original_id': '101', 'unique_id': '100.0.0.R.0.0.R.0.0.100.0.0.R.0.0.100.0.0.101', 'condition_open': True}['index']'
# RETURN [TEXT]: 3
# Requested to load SDXLClipModel
# Loading 1 new model
# loaded completely 0.0 1560.802734375 True
# Requested to load SDXL
# Loading 1 new model
# loaded completely 9.5367431640625e+25 4897.0483474731445 True
# 100%|██████████| 5/5 [00:07<00:00,  1.48s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# loaded completely 0.0 319.11416244506836 True
# 100%|██████████| 6/6 [00:58<00:00,  9.79s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# loaded completely 0.0 319.11416244506836 True
# INFO: InsightFace detection resolution lowered to (512, 512).
# Requested to load ControlNet
# Requested to load SDXL
# Requested to load ControlNet
# Loading 3 new models
# loaded completely 0.0 2386.120147705078 True
# loaded completely 9.5367431640625e+25 4897.0483474731445 True
# loaded completely 0.0 2396.797637939453 True
#  14%|█▍        | 1/7 [00:14<01:25, 14.19s/it]
# WAS Node Suite: Image file saved to: /kaggle/working/ComfyUI/output/InstantID 2024-11-20-16-30-54_0001.jpeg
# WAS Node Suite: Image file saved to: /kaggle/working/ComfyUI/output/InstantID 2024-11-20-16-30-54_0002.jpeg
# WAS Node Suite: Image file saved to: /kaggle/working/ComfyUI/output/InstantID 2024-11-20-16-30-54_0003.jpeg
# WAS Node Suite: Image file saved to: /kaggle/working/ComfyUI/output/InstantID 2024-11-20-16-30-54_0004.jpeg
# HTTP Request: POST https://upload.uploadcare.com/base/ "HTTP/1.1 200 OK"
# HTTP Request: POST https://upload.uploadcare.com/base/ "HTTP/1.1 200 OK"
# HTTP Request: POST https://upload.uploadcare.com/base/ "HTTP/1.1 200 OK"
#  29%|██▊       | 2/7 [00:28<01:11, 14.37s/it]HTTP Request: POST https://upload.uploadcare.com/base/ "HTTP/1.1 200 OK"
# >> JOINING PRIMITIVE ' input2 ' INTO BATCH!
#
# >> LOOP [ 101 ] CLOSE
#
# >> LOOP [ 101 ] ITERATION: 2
# VARS= {'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 2, 'finished': False, 'last_id': '100.0.0.R.0.0.100.0.0.101', 'data': 0, 'aux': ('https://ucarecdn.com/dd87fb94-59e8-401c-90d7-4c6587cdfb62/', 'https://ucarecdn.com/c0857486-99e4-4a67-8e90-952aaa200863/'), 'index_override': 2, 'original_id': '101', 'unique_id': '100.0.0.R.0.0.100.0.0.101'}
#
# >> DATA MONITOR [ 100 ]
# TEXT:  %aux%['index']
# PASSTHROUGH:  <class 'NoneType'> None
# AUX INPUTS:  [{'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 2, 'finished': False, 'last_id': '100.0.0.R.0.0.100.0.0.101', 'data': 0, 'aux': ('https://ucarecdn.com/dd87fb94-59e8-401c-90d7-4c6587cdfb62/', 'https://ucarecdn.com/c0857486-99e4-4a67-8e90-952aaa200863/'), 'index_override': 2, 'original_id': '101', 'unique_id': '100.0.0.R.0.0.100.0.0.101', 'condition_open': True}, None, None, None, None]
# PREV: {'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 2, 'finished': False, 'last_id': '100.0.0.R.0.0.100.0.0.101', 'data': 0, 'aux': ('https://ucarecdn.com/9cba0503-cd70-416a-b248-9669aa0e9a49/', 'https://ucarecdn.com/f24c4658-ba3f-4729-b402-3bd3c1f69d17/'), 'index_override': 2, 'original_id': '101', 'unique_id': '100.0.0.R.0.0.100.0.0.101', 'condition_open': True}['index']
# OUTPUT TYPE:  FORMULA
# REPLACING '%aux%' in '%aux%['index']' with '{'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 2, 'finished': False, 'last_id': '100.0.0.R.0.0.100.0.0.101', 'data': 0, 'aux': ('https://ucarecdn.com/dd87fb94-59e8-401c-90d7-4c6587cdfb62/', 'https://ucarecdn.com/c0857486-99e4-4a67-8e90-952aaa200863/'), 'index_override': 2, 'original_id': '101', 'unique_id': '100.0.0.R.0.0.100.0.0.101', 'condition_open': True}'!
# >> PROCESSED TEXT AFTER VARIABLE REPLACEMENT: '{'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 2, 'finished': False, 'last_id': '100.0.0.R.0.0.100.0.0.101', 'data': 0, 'aux': ('https://ucarecdn.com/dd87fb94-59e8-401c-90d7-4c6587cdfb62/', 'https://ucarecdn.com/c0857486-99e4-4a67-8e90-952aaa200863/'), 'index_override': 2, 'original_id': '101', 'unique_id': '100.0.0.R.0.0.100.0.0.101', 'condition_open': True}['index']'
# RETURN [TEXT]: 2
# Requested to load SDXLClipModel
# Loading 1 new model
# loaded completely 0.0 1560.802734375 True
# Requested to load SDXL
# Loading 1 new model
# loaded completely 9.5367431640625e+25 4897.0483474731445 True
# 100%|██████████| 5/5 [00:06<00:00,  1.28s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# loaded completely 0.0 319.11416244506836 True
#  43%|████▎     | 3/7 [00:42<00:56, 14.20s/it]
# INFO: InsightFace detection resolution lowered to (512, 512).
# Requested to load ControlNet
# Requested to load SDXL
# Requested to load ControlNet
# Loading 3 new models
# loaded completely 0.0 2396.797637939453 True
# loaded completely 9.5367431640625e+25 4897.0483474731445 True
# loaded completely 0.0 2386.120147705078 True
# 100%|██████████| 7/7 [01:20<00:00, 11.55s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# loaded completely 0.0 319.11416244506836 True
# 100%|██████████| 6/6 [00:57<00:00,  9.57s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# loaded completely 0.0 319.11416244506836 True
# WAS Node Suite: Image file saved to: /kaggle/working/ComfyUI/output/InstantID 2024-11-20-16-32-21_0001.jpeg
# WAS Node Suite: Image file saved to: /kaggle/working/ComfyUI/output/InstantID 2024-11-20-16-32-21_0002.jpeg
# WAS Node Suite: Image file saved to: /kaggle/working/ComfyUI/output/InstantID 2024-11-20-16-32-21_0003.jpeg
# WAS Node Suite: Image file saved to: /kaggle/working/ComfyUI/output/InstantID 2024-11-20-16-32-21_0004.jpeg
# HTTP Request: POST https://upload.uploadcare.com/base/ "HTTP/1.1 200 OK"
# HTTP Request: POST https://upload.uploadcare.com/base/ "HTTP/1.1 200 OK"
# HTTP Request: POST https://upload.uploadcare.com/base/ "HTTP/1.1 200 OK"
# HTTP Request: POST https://upload.uploadcare.com/base/ "HTTP/1.1 200 OK"
# >> JOINING PRIMITIVE ' input2 ' INTO BATCH!
#
# >> LOOP [ 101 ] CLOSE
#
# >> LOOP [ 101 ] ITERATION: 4
# VARS= {'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 4, 'finished': True, 'last_id': '100.0.0.R.0.0.R.0.0.R.0.0.100.0.0.R.0.0.R.0.0.100.0.0.R.0.0.100.0.0.101', 'data': 0, 'aux': ('https://ucarecdn.com/5f93b72a-5854-48f4-b1a6-ce92d40d400e/', 'https://ucarecdn.com/275c29a3-2dce-4d36-8f0d-00844c0946a2/', 'https://ucarecdn.com/e0f61440-2169-4246-8e6b-31d901434243/', 'https://ucarecdn.com/ae5a2807-59bb-4fec-a7bd-b116d149b420/'), 'index_override': 4, 'original_id': '101', 'unique_id': '100.0.0.R.0.0.R.0.0.R.0.0.100.0.0.R.0.0.R.0.0.100.0.0.R.0.0.100.0.0.101'}
#
# >> DATA MONITOR [ 100 ]
# TEXT:  %aux%['index']
# PASSTHROUGH:  <class 'NoneType'> None
# AUX INPUTS:  [{'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 4, 'finished': True, 'last_id': '100.0.0.R.0.0.R.0.0.R.0.0.100.0.0.R.0.0.R.0.0.100.0.0.R.0.0.100.0.0.101', 'data': 0, 'aux': ('https://ucarecdn.com/5f93b72a-5854-48f4-b1a6-ce92d40d400e/', 'https://ucarecdn.com/275c29a3-2dce-4d36-8f0d-00844c0946a2/', 'https://ucarecdn.com/e0f61440-2169-4246-8e6b-31d901434243/', 'https://ucarecdn.com/ae5a2807-59bb-4fec-a7bd-b116d149b420/'), 'index_override': 4, 'original_id': '101', 'unique_id': '100.0.0.R.0.0.R.0.0.R.0.0.100.0.0.R.0.0.R.0.0.100.0.0.R.0.0.100.0.0.101', 'condition_open': True}, None, None, None, None]
# PREV: {'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 4, 'finished': True, 'last_id': '100.0.0.R.0.0.R.0.0.R.0.0.100.0.0.R.0.0.R.0.0.100.0.0.R.0.0.100.0.0.101', 'data': 0, 'aux': ('https://ucarecdn.com/33d859dc-cefe-46e8-9eba-23faa729cd07/', 'https://ucarecdn.com/4e2f270f-9753-4361-bd64-f59d4cf2c4fb/', 'https://ucarecdn.com/1df13082-bc56-4cb8-b387-47b7da2e07cc/', 'https://ucarecdn.com/06542681-d34a-473f-9c79-0515328b16e1/'), 'index_override': 4, 'original_id': '101', 'unique_id': '100.0.0.R.0.0.R.0.0.R.0.0.100.0.0.R.0.0.R.0.0.100.0.0.R.0.0.100.0.0.101', 'condition_open': True}['index']
# OUTPUT TYPE:  FORMULA
# REPLACING '%aux%' in '%aux%['index']' with '{'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 4, 'finished': True, 'last_id': '100.0.0.R.0.0.R.0.0.R.0.0.100.0.0.R.0.0.R.0.0.100.0.0.R.0.0.100.0.0.101', 'data': 0, 'aux': ('https://ucarecdn.com/5f93b72a-5854-48f4-b1a6-ce92d40d400e/', 'https://ucarecdn.com/275c29a3-2dce-4d36-8f0d-00844c0946a2/', 'https://ucarecdn.com/e0f61440-2169-4246-8e6b-31d901434243/', 'https://ucarecdn.com/ae5a2807-59bb-4fec-a7bd-b116d149b420/'), 'index_override': 4, 'original_id': '101', 'unique_id': '100.0.0.R.0.0.R.0.0.R.0.0.100.0.0.R.0.0.R.0.0.100.0.0.R.0.0.100.0.0.101', 'condition_open': True}'!
# >> PROCESSED TEXT AFTER VARIABLE REPLACEMENT: '{'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 4, 'finished': True, 'last_id': '100.0.0.R.0.0.R.0.0.R.0.0.100.0.0.R.0.0.R.0.0.100.0.0.R.0.0.100.0.0.101', 'data': 0, 'aux': ('https://ucarecdn.com/5f93b72a-5854-48f4-b1a6-ce92d40d400e/', 'https://ucarecdn.com/275c29a3-2dce-4d36-8f0d-00844c0946a2/', 'https://ucarecdn.com/e0f61440-2169-4246-8e6b-31d901434243/', 'https://ucarecdn.com/ae5a2807-59bb-4fec-a7bd-b116d149b420/'), 'index_override': 4, 'original_id': '101', 'unique_id': '100.0.0.R.0.0.R.0.0.R.0.0.100.0.0.R.0.0.R.0.0.100.0.0.R.0.0.100.0.0.101', 'condition_open': True}['index']'
# RETURN [TEXT]: 4
# Requested to load SDXLClipModel
# Loading 1 new model
# loaded completely 0.0 1560.802734375 True
# Requested to load SDXL
# Loading 1 new model
# loaded completely 9.5367431640625e+25 4897.0483474731445 True
# 100%|██████████| 5/5 [00:06<00:00,  1.39s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# loaded completely 0.0 319.11416244506836 True
# Error handling request
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/aiohttp/web_protocol.py", line 350, in data_received
#     messages, upgraded, tail = self._request_parser.feed_data(data)
#   File "aiohttp/_http_parser.pyx", line 557, in aiohttp._http_parser.HttpParser.feed_data
# aiohttp.http_exceptions.BadStatusLine: 400, message:
#   Invalid method encountered:
#
#     b'\x16\x03\x01\x01\n\x01'
#       ^
# Error handling request
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/aiohttp/web_protocol.py", line 350, in data_received
#     messages, upgraded, tail = self._request_parser.feed_data(data)
#   File "aiohttp/_http_parser.pyx", line 557, in aiohttp._http_parser.HttpParser.feed_data
# aiohttp.http_exceptions.BadStatusLine: 400, message:
#   Invalid method encountered:
#
#     b'\x16\x03\x01\x01\n\x01'
#       ^
# Error handling request
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/aiohttp/web_protocol.py", line 350, in data_received
#     messages, upgraded, tail = self._request_parser.feed_data(data)
#   File "aiohttp/_http_parser.pyx", line 557, in aiohttp._http_parser.HttpParser.feed_data
# aiohttp.http_exceptions.BadStatusLine: 400, message:
#   Invalid method encountered:
#
#     b'\x16\x03\x01\x01\n\x01'
#       ^
# WAS Node Suite: Image file saved to: /kaggle/working/ComfyUI/output/InstantID 2024-11-20-16-32-44_0001.jpeg
# WAS Node Suite: Image file saved to: /kaggle/working/ComfyUI/output/InstantID 2024-11-20-16-32-44_0002.jpeg
# WAS Node Suite: Image file saved to: /kaggle/working/ComfyUI/output/InstantID 2024-11-20-16-32-44_0003.jpeg
# WAS Node Suite: Image file saved to: /kaggle/working/ComfyUI/output/InstantID 2024-11-20-16-32-44_0004.jpeg
# Error handling request
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/aiohttp/web_protocol.py", line 350, in data_received
#     messages, upgraded, tail = self._request_parser.feed_data(data)
#   File "aiohttp/_http_parser.pyx", line 557, in aiohttp._http_parser.HttpParser.feed_data
# aiohttp.http_exceptions.BadStatusLine: 400, message:
#   Invalid method encountered:
#
#     b'\x16\x03\x01\x01\n\x01'
#       ^
# Error handling request
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/aiohttp/web_protocol.py", line 350, in data_received
#     messages, upgraded, tail = self._request_parser.feed_data(data)
#   File "aiohttp/_http_parser.pyx", line 557, in aiohttp._http_parser.HttpParser.feed_data
# aiohttp.http_exceptions.BadStatusLine: 400, message:
#   Invalid method encountered:
#
#     b'\x16\x03\x01\x01\n\x01'
#       ^
# Error handling request
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/aiohttp/web_protocol.py", line 350, in data_received
#     messages, upgraded, tail = self._request_parser.feed_data(data)
#   File "aiohttp/_http_parser.pyx", line 557, in aiohttp._http_parser.HttpParser.feed_data
# aiohttp.http_exceptions.BadStatusLine: 400, message:
#   Invalid method encountered:
#
#     b'\x16\x03\x01\x01\n\x01'
#       ^
# Error handling request
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/aiohttp/web_protocol.py", line 350, in data_received
#     messages, upgraded, tail = self._request_parser.feed_data(data)
#   File "aiohttp/_http_parser.pyx", line 557, in aiohttp._http_parser.HttpParser.feed_data
# aiohttp.http_exceptions.BadStatusLine: 400, message:
#   Invalid method encountered:
#
#     b'\x16\x03\x01\x01\n\x01'
#       ^
# Error handling request
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/aiohttp/web_protocol.py", line 350, in data_received
#     messages, upgraded, tail = self._request_parser.feed_data(data)
#   File "aiohttp/_http_parser.pyx", line 557, in aiohttp._http_parser.HttpParser.feed_data
# aiohttp.http_exceptions.BadStatusLine: 400, message:
#   Invalid method encountered:
#
#     b'\x16\x03\x01\x01\n\x01'
#       ^
# Error handling request
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/aiohttp/web_protocol.py", line 350, in data_received
#     messages, upgraded, tail = self._request_parser.feed_data(data)
#   File "aiohttp/_http_parser.pyx", line 557, in aiohttp._http_parser.HttpParser.feed_data
# aiohttp.http_exceptions.BadStatusLine: 400, message:
#   Invalid method encountered:
#
#     b'\x16\x03\x01\x01\n\x01'
#       ^
# HTTP Request: POST https://upload.uploadcare.com/base/ "HTTP/1.1 200 OK"
# Error handling request
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/aiohttp/web_protocol.py", line 350, in data_received
#     messages, upgraded, tail = self._request_parser.feed_data(data)
#   File "aiohttp/_http_parser.pyx", line 557, in aiohttp._http_parser.HttpParser.feed_data
# aiohttp.http_exceptions.BadStatusLine: 400, message:
#   Invalid method encountered:
#
#     b'\x16\x03\x01\x01\n\x01'
#       ^
# INFO: InsightFace detection resolution lowered to (512, 512).
# HTTP Request: POST https://upload.uploadcare.com/base/ "HTTP/1.1 200 OK"
# Requested to load ControlNet
# Requested to load SDXL
# Requested to load ControlNet
# Loading 3 new models
# loaded completely 0.0 2386.120147705078 True
# loaded completely 9.5367431640625e+25 4897.0483474731445 True
# loaded completely 0.0 2396.797637939453 True
#   0%|          | 0/7 [00:00<?, ?it/s]HTTP Request: POST https://upload.uploadcare.com/base/ "HTTP/1.1 200 OK"
# HTTP Request: POST https://upload.uploadcare.com/base/ "HTTP/1.1 200 OK"
# >> JOINING PRIMITIVE ' input2 ' INTO BATCH!
#
# >> LOOP [ 101 ] CLOSE
#
# >> LOOP [ 101 ] ITERATION: 3
# VARS= {'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 3, 'finished': False, 'last_id': '100.0.0.R.0.0.R.0.0.100.0.0.R.0.0.100.0.0.101', 'data': 0, 'aux': ('https://ucarecdn.com/dd87fb94-59e8-401c-90d7-4c6587cdfb62/', 'https://ucarecdn.com/c0857486-99e4-4a67-8e90-952aaa200863/', 'https://ucarecdn.com/709ec5cc-bf11-4027-949f-613413a9ea0a/'), 'index_override': 3, 'original_id': '101', 'unique_id': '100.0.0.R.0.0.R.0.0.100.0.0.R.0.0.100.0.0.101'}
#
# >> DATA MONITOR [ 100 ]
# TEXT:  %aux%['index']
# PASSTHROUGH:  <class 'NoneType'> None
# AUX INPUTS:  [{'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 3, 'finished': False, 'last_id': '100.0.0.R.0.0.R.0.0.100.0.0.R.0.0.100.0.0.101', 'data': 0, 'aux': ('https://ucarecdn.com/dd87fb94-59e8-401c-90d7-4c6587cdfb62/', 'https://ucarecdn.com/c0857486-99e4-4a67-8e90-952aaa200863/', 'https://ucarecdn.com/709ec5cc-bf11-4027-949f-613413a9ea0a/'), 'index_override': 3, 'original_id': '101', 'unique_id': '100.0.0.R.0.0.R.0.0.100.0.0.R.0.0.100.0.0.101', 'condition_open': True}, None, None, None, None]
# PREV: {'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 3, 'finished': False, 'last_id': '100.0.0.R.0.0.R.0.0.100.0.0.R.0.0.100.0.0.101', 'data': 0, 'aux': ('https://ucarecdn.com/9cba0503-cd70-416a-b248-9669aa0e9a49/', 'https://ucarecdn.com/f24c4658-ba3f-4729-b402-3bd3c1f69d17/', 'https://ucarecdn.com/fd62fda4-2efd-46cf-bffc-86b356a8c5f2/'), 'index_override': 3, 'original_id': '101', 'unique_id': '100.0.0.R.0.0.R.0.0.100.0.0.R.0.0.100.0.0.101', 'condition_open': True}['index']
# OUTPUT TYPE:  FORMULA
# REPLACING '%aux%' in '%aux%['index']' with '{'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 3, 'finished': False, 'last_id': '100.0.0.R.0.0.R.0.0.100.0.0.R.0.0.100.0.0.101', 'data': 0, 'aux': ('https://ucarecdn.com/dd87fb94-59e8-401c-90d7-4c6587cdfb62/', 'https://ucarecdn.com/c0857486-99e4-4a67-8e90-952aaa200863/', 'https://ucarecdn.com/709ec5cc-bf11-4027-949f-613413a9ea0a/'), 'index_override': 3, 'original_id': '101', 'unique_id': '100.0.0.R.0.0.R.0.0.100.0.0.R.0.0.100.0.0.101', 'condition_open': True}'!
# >> PROCESSED TEXT AFTER VARIABLE REPLACEMENT: '{'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 3, 'finished': False, 'last_id': '100.0.0.R.0.0.R.0.0.100.0.0.R.0.0.100.0.0.101', 'data': 0, 'aux': ('https://ucarecdn.com/dd87fb94-59e8-401c-90d7-4c6587cdfb62/', 'https://ucarecdn.com/c0857486-99e4-4a67-8e90-952aaa200863/', 'https://ucarecdn.com/709ec5cc-bf11-4027-949f-613413a9ea0a/'), 'index_override': 3, 'original_id': '101', 'unique_id': '100.0.0.R.0.0.R.0.0.100.0.0.R.0.0.100.0.0.101', 'condition_open': True}['index']'
# RETURN [TEXT]: 3
# Requested to load SDXLClipModel
# Loading 1 new model
# loaded completely 0.0 1560.802734375 True
# Requested to load SDXL
# Loading 1 new model
# loaded completely 9.5367431640625e+25 4897.0483474731445 True
# 100%|██████████| 5/5 [00:06<00:00,  1.28s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# loaded completely 0.0 319.11416244506836 True
#  14%|█▍        | 1/7 [00:14<01:26, 14.46s/it]Error handling request
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/aiohttp/web_protocol.py", line 350, in data_received
#     messages, upgraded, tail = self._request_parser.feed_data(data)
#   File "aiohttp/_http_parser.pyx", line 557, in aiohttp._http_parser.HttpParser.feed_data
# aiohttp.http_exceptions.BadStatusLine: 400, message:
#   Invalid method encountered:
#
#     b'\x16\x03\x01\x01\x16\x01'
#       ^
# Error handling request
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/aiohttp/web_protocol.py", line 350, in data_received
#     messages, upgraded, tail = self._request_parser.feed_data(data)
#   File "aiohttp/_http_parser.pyx", line 557, in aiohttp._http_parser.HttpParser.feed_data
# aiohttp.http_exceptions.BadStatusLine: 400, message:
#   Invalid method encountered:
#
#     b'\x16\x03\x01'
#       ^
# Error handling request
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/aiohttp/web_protocol.py", line 350, in data_received
#     messages, upgraded, tail = self._request_parser.feed_data(data)
#   File "aiohttp/_http_parser.pyx", line 557, in aiohttp._http_parser.HttpParser.feed_data
# aiohttp.http_exceptions.BadStatusLine: 400, message:
#   Invalid method encountered:
#
#     b'\x16\x03\x01'
#       ^
# INFO: InsightFace detection resolution lowered to (512, 512).
# Requested to load ControlNet
# Requested to load SDXL
# Requested to load ControlNet
# Loading 3 new models
# loaded completely 0.0 2396.797637939453 True
# loaded completely 9.5367431640625e+25 4897.0483474731445 True
# loaded completely 0.0 2386.120147705078 True
# 100%|██████████| 6/6 [00:57<00:00,  9.56s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# loaded completely 0.0 319.11416244506836 True
# 100%|██████████| 7/7 [01:22<00:00, 11.84s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# loaded completely 0.0 319.11416244506836 True
# WAS Node Suite: Image file saved to: /kaggle/working/ComfyUI/output/InstantID 2024-11-20-16-34-35_0001.jpeg
# WAS Node Suite: Image file saved to: /kaggle/working/ComfyUI/output/InstantID 2024-11-20-16-34-35_0002.jpeg
# WAS Node Suite: Image file saved to: /kaggle/working/ComfyUI/output/InstantID 2024-11-20-16-34-35_0003.jpeg
# WAS Node Suite: Image file saved to: /kaggle/working/ComfyUI/output/InstantID 2024-11-20-16-34-35_0004.jpeg
# HTTP Request: POST https://upload.uploadcare.com/base/ "HTTP/1.1 200 OK"
# HTTP Request: POST https://upload.uploadcare.com/base/ "HTTP/1.1 200 OK"
# HTTP Request: POST https://upload.uploadcare.com/base/ "HTTP/1.1 200 OK"
# HTTP Request: POST https://upload.uploadcare.com/base/ "HTTP/1.1 200 OK"
# >> JOINING PRIMITIVE ' input2 ' INTO BATCH!
#
# >> LOOP [ 101 ] CLOSE
#
# >> LOOP [ 101 ] ITERATION: 4
# VARS= {'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 4, 'finished': True, 'last_id': '100.0.0.R.0.0.R.0.0.R.0.0.100.0.0.R.0.0.R.0.0.100.0.0.R.0.0.100.0.0.101', 'data': 0, 'aux': ('https://ucarecdn.com/dd87fb94-59e8-401c-90d7-4c6587cdfb62/', 'https://ucarecdn.com/c0857486-99e4-4a67-8e90-952aaa200863/', 'https://ucarecdn.com/709ec5cc-bf11-4027-949f-613413a9ea0a/', 'https://ucarecdn.com/911e6a65-c81f-4b32-a9a8-18492c7e6831/'), 'index_override': 4, 'original_id': '101', 'unique_id': '100.0.0.R.0.0.R.0.0.R.0.0.100.0.0.R.0.0.R.0.0.100.0.0.R.0.0.100.0.0.101'}
#
# >> DATA MONITOR [ 100 ]
# TEXT:  %aux%['index']
# PASSTHROUGH:  <class 'NoneType'> None
# AUX INPUTS:  [{'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 4, 'finished': True, 'last_id': '100.0.0.R.0.0.R.0.0.R.0.0.100.0.0.R.0.0.R.0.0.100.0.0.R.0.0.100.0.0.101', 'data': 0, 'aux': ('https://ucarecdn.com/dd87fb94-59e8-401c-90d7-4c6587cdfb62/', 'https://ucarecdn.com/c0857486-99e4-4a67-8e90-952aaa200863/', 'https://ucarecdn.com/709ec5cc-bf11-4027-949f-613413a9ea0a/', 'https://ucarecdn.com/911e6a65-c81f-4b32-a9a8-18492c7e6831/'), 'index_override': 4, 'original_id': '101', 'unique_id': '100.0.0.R.0.0.R.0.0.R.0.0.100.0.0.R.0.0.R.0.0.100.0.0.R.0.0.100.0.0.101', 'condition_open': True}, None, None, None, None]
# PREV: {'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 4, 'finished': True, 'last_id': '100.0.0.R.0.0.R.0.0.R.0.0.100.0.0.R.0.0.R.0.0.100.0.0.R.0.0.100.0.0.101', 'data': 0, 'aux': ('https://ucarecdn.com/9cba0503-cd70-416a-b248-9669aa0e9a49/', 'https://ucarecdn.com/f24c4658-ba3f-4729-b402-3bd3c1f69d17/', 'https://ucarecdn.com/fd62fda4-2efd-46cf-bffc-86b356a8c5f2/', 'https://ucarecdn.com/09271131-7f4f-4d9b-ae8e-692df168f0cc/'), 'index_override': 4, 'original_id': '101', 'unique_id': '100.0.0.R.0.0.R.0.0.R.0.0.100.0.0.R.0.0.R.0.0.100.0.0.R.0.0.100.0.0.101', 'condition_open': True}['index']
# OUTPUT TYPE:  FORMULA
# REPLACING '%aux%' in '%aux%['index']' with '{'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 4, 'finished': True, 'last_id': '100.0.0.R.0.0.R.0.0.R.0.0.100.0.0.R.0.0.R.0.0.100.0.0.R.0.0.100.0.0.101', 'data': 0, 'aux': ('https://ucarecdn.com/dd87fb94-59e8-401c-90d7-4c6587cdfb62/', 'https://ucarecdn.com/c0857486-99e4-4a67-8e90-952aaa200863/', 'https://ucarecdn.com/709ec5cc-bf11-4027-949f-613413a9ea0a/', 'https://ucarecdn.com/911e6a65-c81f-4b32-a9a8-18492c7e6831/'), 'index_override': 4, 'original_id': '101', 'unique_id': '100.0.0.R.0.0.R.0.0.R.0.0.100.0.0.R.0.0.R.0.0.100.0.0.R.0.0.100.0.0.101', 'condition_open': True}'!
# >> PROCESSED TEXT AFTER VARIABLE REPLACEMENT: '{'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 4, 'finished': True, 'last_id': '100.0.0.R.0.0.R.0.0.R.0.0.100.0.0.R.0.0.R.0.0.100.0.0.R.0.0.100.0.0.101', 'data': 0, 'aux': ('https://ucarecdn.com/dd87fb94-59e8-401c-90d7-4c6587cdfb62/', 'https://ucarecdn.com/c0857486-99e4-4a67-8e90-952aaa200863/', 'https://ucarecdn.com/709ec5cc-bf11-4027-949f-613413a9ea0a/', 'https://ucarecdn.com/911e6a65-c81f-4b32-a9a8-18492c7e6831/'), 'index_override': 4, 'original_id': '101', 'unique_id': '100.0.0.R.0.0.R.0.0.R.0.0.100.0.0.R.0.0.R.0.0.100.0.0.R.0.0.100.0.0.101', 'condition_open': True}['index']'
# RETURN [TEXT]: 4
# WAS Node Suite: Image file saved to: /kaggle/working/ComfyUI/output/InstantID 2024-11-20-16-34-42_0001.jpeg
# WAS Node Suite: Image file saved to: /kaggle/working/ComfyUI/output/InstantID 2024-11-20-16-34-42_0002.jpeg
# WAS Node Suite: Image file saved to: /kaggle/working/ComfyUI/output/InstantID 2024-11-20-16-34-42_0003.jpeg
# WAS Node Suite: Image file saved to: /kaggle/working/ComfyUI/output/InstantID 2024-11-20-16-34-42_0004.jpeg
# Requested to load SDXLClipModel
# Loading 1 new model
# loaded completely 0.0 1560.802734375 True
# HTTP Request: POST https://upload.uploadcare.com/base/ "HTTP/1.1 200 OK"
# Requested to load SDXL
# Loading 1 new model
# loaded completely 9.5367431640625e+25 4897.0483474731445 True
#   0%|          | 0/5 [00:00<?, ?it/s]HTTP Request: POST https://upload.uploadcare.com/base/ "HTTP/1.1 200 OK"
#  20%|██        | 1/5 [00:01<00:05,  1.40s/it]HTTP Request: POST https://upload.uploadcare.com/base/ "HTTP/1.1 200 OK"
# HTTP Request: POST https://upload.uploadcare.com/base/ "HTTP/1.1 200 OK"
# Prompt executed in 706.45 seconds
#  40%|████      | 2/5 [00:02<00:04,  1.42s/it]
# >> JOINING PRIMITIVE ' input2 ' INTO BATCH!
#
# >> LOOP [ 101 ] CLOSE
#
# LOOP [ 101 ] FINISHED!
# got prompt
#  60%|██████    | 3/5 [00:04<00:02,  1.43s/it]WARNING: PlaySound.IS_CHANGED() missing 1 required positional argument: 'self'
# >> DATA MONITOR [ 104 ]
# TEXT:  %aux%['index']
# PASSTHROUGH:  <class 'NoneType'> None
# AUX INPUTS:  [{'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 0, 'finished': False, 'last_id': '101', 'data': 0, 'unique_id': '101', 'condition_open': True, 'condition_close': 'True', 'aux': 'https://ucarecdn.com/5f93b72a-5854-48f4-b1a6-ce92d40d400e/'}, None, None, None, None]
# PREV: {'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 0, 'finished': False, 'last_id': '101', 'data': 0, 'unique_id': '101', 'condition_open': True, 'condition_close': 'True', 'aux': 'https://ucarecdn.com/33d859dc-cefe-46e8-9eba-23faa729cd07/'}['index']
# OUTPUT TYPE:  FORMULA
# REPLACING '%aux%' in '%aux%['index']' with '{'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 0, 'finished': False, 'last_id': '101', 'data': 0, 'unique_id': '101', 'condition_open': True, 'condition_close': 'True', 'aux': 'https://ucarecdn.com/5f93b72a-5854-48f4-b1a6-ce92d40d400e/'}'!
# >> PROCESSED TEXT AFTER VARIABLE REPLACEMENT: '{'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 0, 'finished': False, 'last_id': '101', 'data': 0, 'unique_id': '101', 'condition_open': True, 'condition_close': 'True', 'aux': 'https://ucarecdn.com/5f93b72a-5854-48f4-b1a6-ce92d40d400e/'}['index']'
# RETURN [TEXT]: 0
# 100%|██████████| 5/5 [00:06<00:00,  1.28s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# loaded completely 0.0 319.11416244506836 True
# Requested to load SDXLClipModel
# Loading 1 new model
# loaded completely 0.0 1560.802734375 True
# Requested to load SDXL
# Loading 1 new model
# loaded completely 9.5367431640625e+25 4897.0483474731445 True
#  20%|██        | 1/5 [00:01<00:06,  1.58s/it]
# INFO: InsightFace detection resolution lowered to (512, 512).
#  40%|████      | 2/5 [00:03<00:04,  1.63s/it]Requested to load ControlNet
# Requested to load SDXL
# Requested to load ControlNet
# Loading 3 new models
# loaded completely 0.0 2396.797637939453 True
# loaded completely 9.5367431640625e+25 4897.0483474731445 True
# loaded completely 0.0 2386.120147705078 True
# 100%|██████████| 5/5 [00:07<00:00,  1.44s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# loaded completely 0.0 319.11416244506836 True
# INFO: InsightFace detection resolution lowered to (512, 512).
#  17%|█▋        | 1/6 [00:11<00:57, 11.50s/it]Requested to load ControlNet
# Requested to load SDXL
# Requested to load ControlNet
# Loading 3 new models
# loaded completely 0.0 2386.120147705078 True
# loaded completely 9.5367431640625e+25 4897.0483474731445 True
# loaded completely 0.0 2396.797637939453 True
# 100%|██████████| 6/6 [00:57<00:00,  9.57s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# loaded completely 0.0 319.11416244506836 True
#  71%|███████▏  | 5/7 [01:07<00:25, 12.76s/it]
# WAS Node Suite: Image file saved to: /kaggle/working/ComfyUI/output/InstantID 2024-11-20-16-36-25_0001.jpeg
# WAS Node Suite: Image file saved to: /kaggle/working/ComfyUI/output/InstantID 2024-11-20-16-36-25_0002.jpeg
# WAS Node Suite: Image file saved to: /kaggle/working/ComfyUI/output/InstantID 2024-11-20-16-36-25_0003.jpeg
# WAS Node Suite: Image file saved to: /kaggle/working/ComfyUI/output/InstantID 2024-11-20-16-36-25_0004.jpeg
# HTTP Request: POST https://upload.uploadcare.com/base/ "HTTP/1.1 200 OK"
# HTTP Request: POST https://upload.uploadcare.com/base/ "HTTP/1.1 200 OK"
# HTTP Request: POST https://upload.uploadcare.com/base/ "HTTP/1.1 200 OK"
# HTTP Request: POST https://upload.uploadcare.com/base/ "HTTP/1.1 200 OK"
# Prompt executed in 557.49 seconds
# >> JOINING PRIMITIVE ' input2 ' INTO BATCH!
#
# >> LOOP [ 101 ] CLOSE
#
# LOOP [ 101 ] FINISHED!
# got prompt
#  86%|████████▌ | 6/7 [01:18<00:12, 12.08s/it]WARNING: PlaySound.IS_CHANGED() missing 1 required positional argument: 'self'
# >> DATA MONITOR [ 104 ]
# TEXT:  %aux%['index']
# PASSTHROUGH:  <class 'NoneType'> None
# AUX INPUTS:  [{'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 0, 'finished': False, 'last_id': '101', 'data': 0, 'unique_id': '101', 'condition_open': True, 'condition_close': 'True', 'aux': 'https://ucarecdn.com/dd87fb94-59e8-401c-90d7-4c6587cdfb62/'}, None, None, None, None]
# PREV: {'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 0, 'finished': False, 'last_id': '101', 'data': 0, 'unique_id': '101', 'condition_open': True, 'condition_close': 'True', 'aux': 'https://ucarecdn.com/9cba0503-cd70-416a-b248-9669aa0e9a49/'}['index']
# OUTPUT TYPE:  FORMULA
# REPLACING '%aux%' in '%aux%['index']' with '{'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 0, 'finished': False, 'last_id': '101', 'data': 0, 'unique_id': '101', 'condition_open': True, 'condition_close': 'True', 'aux': 'https://ucarecdn.com/dd87fb94-59e8-401c-90d7-4c6587cdfb62/'}'!
# >> PROCESSED TEXT AFTER VARIABLE REPLACEMENT: '{'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 0, 'finished': False, 'last_id': '101', 'data': 0, 'unique_id': '101', 'condition_open': True, 'condition_close': 'True', 'aux': 'https://ucarecdn.com/dd87fb94-59e8-401c-90d7-4c6587cdfb62/'}['index']'
# RETURN [TEXT]: 0

# %%
# !ps fx

# %% [raw]
# !kill 414 435

# %% [raw]
# !ln -s /kaggle/input/realvisxl-v50/pytorch/default/1/realvisxl-v50.safetensors  /kaggle/working/ComfyUI/models/checkpoints/realvisxl-v50

# %%
# !du --max-depth 1 /kaggle/working/ComfyUI/models/ -lc | sort -k1 -n

# %%
# !ls -ltrha  /kaggle/working/ComfyUI/models/ipadapter/ #-lc | sort -k1 -n
# !rm /kaggle/working/ComfyUI/models/ipadapter/ip-adapter-faceid-plusv2_sdxl.bin #/kaggle/working/ComfyUI/models/instantid/SDXL/ip-adapter.bin

# %%
# !ls -ltrha  /kaggle/working/ComfyUI/models/facerestore_models #-lc | sort -k1 -n

# %% [raw]
# # !rm /kaggle/working/ComfyUI/models/facerestore_models/*

# %%
from IPython.display import display, HTML, FileLink

display(HTML("<style>.container { width:100% !important; }</style>"))
from IPython.display import display, HTML

display(HTML("<style>.output_area pre { white-space: pre-wrap; }</style>"))
os.chdir("/kaggle/working/")
display(FileLink('output_18112024_1959.zip.zip'))
os.chdir("/kaggle/working/ComfyUI/")

# %%
# !ps fax

# %% [raw]
#  # !mkdir /kaggle/working/ComfyUI/logs

# %%
# !rm playit-linux-amd64*

# %%
os.chdir("/kaggle/working/ComfyUI/")
if  not os.path.exists('/kaggle/working/ComfyUI/playit-linux-amd64'):
    # !wget https://github.com/playit-cloud/playit-agent/releases/download/v0.15.26/playit-linux-amd64
# !chmod 777 /kaggle/working/ComfyUI/playit-linux-amd64

# !ls -ltrha play*

# %%
# !wget https://github.com/playit-cloud/playit-agent/releases/download/v0.15.26/playit-linux-amd64 -q
# !chmod +x ./playit-linux-amd64 
# !./playit-linux-amd64  --help

# %%
subprocess.Popen("nohup /kaggle/working/ComfyUI/playit-linux-amd64   >> /kaggle/working/ComfyUI/logs/playit.log 2>&1 & echo 'done' ",bufsize=0,shell=True)

# %%
# !tail -n 20 /kaggle/working/ComfyUI/logs/playit.log

# %%
# !ps fax

# %% [markdown]
# # !rm /kaggle/working/ComfyUI/models/controlnet/*

# %%
# !ls -trha /kaggle/input/sdxl_controlnets/pytorch/default/2

# %%
# !ls -ltrha /kaggle/working/ComfyUI/models/controlnet

# %%
# !ls -ltrha /kaggle/working/ComfyUI/models/controlnet/SDXL

# %% [raw]
# !rm /kaggle/working/ComfyUI/models/controlnet/OpenPoseXL2.safetensors
# !rm /kaggle/working/ComfyUI/models/controlnet/depth-zoe-xl-v1.0-controlnet.safetensors

# %%
# !kill 1471

# %%
# !wget https://github.com/playit-cloud/playit-agent/releases/download/v0.15.26/playit-linux-amd64 -q
# !chmod +x ./playit-linux-amd64 
# !./playit-linux-amd64  --help

# %%
subprocess.Popen(["/kaggle/working/ComfyUI/playit-linux-amd64","-l","playit.log"],shell=True)

# %%
# !ps fax

# %%
# !df -h

# %%
# !df -h /kaggle/working

# %%
# !du --help

# %%
# !du -h -d1  /kaggle/working/ComfyUI/models | sort -k1

# %%
# !du -h   /kaggle/working/ComfyUI/models/controlnet | sort -k1

# %%
# !rm /kaggle/working/ComfyUI/models/controlnet/SDXL/controlnet-tile-sdxl-1.0/ -r

# %%
# !sudo apt install net-tools -q

# %%
# !netstat -nltp

# %%
# !kill 1059 1146 1159 1177

# %% [raw]
# !./playit-linux-amd64

# %%
subprocess.run("/kaggle/working/ComfyUI/playit-linux-amd64 tunnels list &",shell=True)

# %% [raw]
# port=8188
# command = f"cd /kaggle/working/ComfyUI/ ; nohup /kaggle/working/ComfyUI/playit-linux-amd64 start >> nohup{port}.out 2>&1 & echo $!"
# p = subprocess.Popen(command, shell=True, stdout=subprocess.PIPE)
#
# for line in p.stdout:
#     print(line.decode(), end='')

# %% [raw]
# port=8189
# command = f"nohup ./playit-linux-amd64 >> nohup{port}.out 2>&1 & echo $!"
# p = subprocess.Popen(command, shell=True, stdout=subprocess.PIPE)
#
# for line in p.stdout:
#     print(line.decode(), end='')

# %%
# !kill 1405 1415  1417 1419 1403 1425

# %%
# !ps fax

# %%
## os.chdir("/kaggle/working/ComfyUI/")
subprocess.run("tail -f nohup8188.out &",shell=True)

# %%
import subprocess,os
import threading
import time
import socket
import urllib.request

get_ipython().system("npm install -g npm")
get_ipython().system("npm install -g localtunnel")

# %%
# Change directory to ComfyUI
os.chdir("/kaggle/working/ComfyUI/")

# Launch ComfyUI instances
xP1 = subprocess.Popen(["python", "main.py", "--cuda-device", "0", "--port", "8188","--highvram"])
time.sleep(30)

xP2= subprocess.Popen(["python", "main.py", "--cuda-device", "1", "--port", "8189","--highvram"])
time.sleep(30)
# subprocess.Popen(["./limit_ram.sh","python", "main.py", "--cuda-device", "0", "--port", "8188"])
# subprocess.Popen(["./limit_ram.sh","python", "main.py", "--cuda-device", "1", "--port", "8189"])

# time.sleep(30)

# %%
# !kill 2176 2179  2178 2181

# %%
# !ps fax

# %%
# !wget https://github.com/playit-cloud/playit-agent/releases/download/v0.15.26/playit-linux-amd64

# %%
# !chmod +x ./playit-linux-amd64

# %%
# !./playit-linux-amd64 tunnels list

# %%
# !./playit-linux-amd64 --help

# %%
# !ssh -R 80:localhost:8188 localhost.run

# %%
# !openssl version

# %%
# !ssh -p 443 -R0:localhost:8000 -L4300:localhost:4300 qr@a.pinggy.io

# %%
# !lt --help

# %%
def iframe_thread(port):
  while True:
      time.sleep(0.5)
      sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
      result = sock.connect_ex(('127.0.0.1', port))
      if result == 0:
        break
      sock.close()
  print("\nComfyUI finished loading, trying to launch localtunnel (if it gets stuck here localtunnel is having issues)\n")

  print("The password/enpoint ip for localtunnel is:", urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip("\n"))
#   p = subprocess.Popen(["lt", "--port", "{}".format(port)], stdout=subprocess.PIPE)
  command = f"nohup lt --port {port} --allow-invalid-cert --print-requests >> nohup{port}.out 2>&1 & echo $!"
  p = subprocess.Popen(command, shell=True, stdout=subprocess.PIPE)
  
  for line in p.stdout:
    print(line.decode(), end='')


# threading.Thread(target=iframe_thread, daemon=True, args=(8188,8189,)).start()
# %cd /kaggle/working/ComfyUI/
# # threading.Thread(target=iframe_thread, daemon=True, args=(8189,)).start()
# !python main.py  --cuda-device 0 --port 8188; python main.py --cuda-device 1 --port 8189
# # --dont-print-server

# %%
# Start threads for both ports
xT1 =threading.Thread(target=iframe_thread, daemon=True, args=(8188,))
xT1.start()
xT2 = threading.Thread(target=iframe_thread, daemon=True, args=(8189,)) #.start()
xT2.start()

# %%
subprocess.run("tail -f nohup8188.out &",shell=True)

# %%
subprocess.run("tail -f nohup8189.out &",shell=True)

# %%
# !curl -O https://install.tunnelmole.com/xD345/install && sudo bash install

# %%
port=8188
command = f"nohup tmole {port} >> nohup{port}.out 2>&1 & echo $!"
p = subprocess.Popen(command, shell=True, stdout=subprocess.PIPE)

# %%
# !ps fax

# %% [raw]
# !tail -f nohup8188.out

# %%
subprocess.run("tail -f nohup8188.out &",shell=True)

# %%
port=8189
command = f"nohup tmole {port} >> nohup{port}.out 2>&1 & echo $!"
p2 = subprocess.Popen(command, shell=True, stdout=subprocess.PIPE)

# %%
subprocess.run("tail -f nohup8189.out &",shell=True)

# %%
# %ls /kaggle/working/old_output
# Out:
#  ComfyUI_00001_.png
#  ComfyUI_00002_.png
#  ComfyUI_00003_.png
#  ComfyUI_00004_.png
#  ComfyUI_00005_.png
#  ComfyUI_00006_.png
#  ComfyUI_00007_.png
#  ComfyUI_00008_.png
#  ComfyUI_00009_.png
#  ComfyUI_00010_.png
#  ComfyUI_00011_.png
#  ComfyUI_00012_.png
#  ComfyUI_00013_.png
#  ComfyUI_00014_.png
#  ComfyUI_00015_.png
#  ComfyUI_00016_.png
#  ComfyUI_00017_.png
#  ComfyUI_00018_.png
#  ComfyUI_00019_.png
#  ComfyUI_00020_.png
#  ComfyUI_00021_.png
#  ComfyUI_00022_.png
#  ComfyUI_00023_.png
#  ComfyUI_00024_.png
#  ComfyUI_00025_.png
#  ComfyUI_00026_.png
#  ComfyUI_00027_.png
#  ComfyUI_00028_.png
#  ComfyUI_00029_.png
#  ComfyUI_00030_.png
#  ComfyUI_00031_.png
#  ComfyUI_00032_.png
#  ComfyUI_00033_.png
#  ComfyUI_00034_.png
#  ComfyUI_00035_.png
#  ComfyUI_00036_.png
#  ComfyUI_00037_.png
#  ComfyUI_00038_.png
#  ComfyUI_00039_.png
#  ComfyUI_00040_.png
#  ComfyUI_00041_.png
#  ComfyUI_00042_.png
#  ComfyUI_00043_.png
#  ComfyUI_00044_.png
#  ComfyUI_00045_.png
#  ComfyUI_00046_.png
#  ComfyUI_00047_.png
# Requested to load ControlNet
# Loading 3 new models
# loaded completely 9.5367431640625e+25 4897.0483474731445 True
# loaded completely 0.0 2386.120147705078 True
# loaded completely 0.0 2396.797637939453 True
# 100%|██████████| 18/18 [01:47<00:00,  5.99s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# loaded completely 0.0 319.11416244506836 True
#  33%|███▎      | 6/18 [00:33<01:07,  5.66s/it]
# WAS Node Suite: Image file saved to: /kaggle/working/ComfyUI/output/InstantID 2024-11-20-12-42-55_0001.jpeg
# WAS Node Suite: Image file saved to: /kaggle/working/ComfyUI/output/InstantID 2024-11-20-12-42-55_0002.jpeg
# WAS Node Suite: Image file saved to: /kaggle/working/ComfyUI/output/InstantID 2024-11-20-12-42-55_0003.jpeg
# WAS Node Suite: Image file saved to: /kaggle/working/ComfyUI/output/InstantID 2024-11-20-12-42-55_0004.jpeg
# HTTP Request: POST https://upload.uploadcare.com/base/ "HTTP/1.1 200 OK"
# HTTP Request: POST https://upload.uploadcare.com/base/ "HTTP/1.1 200 OK"
# HTTP Request: POST https://upload.uploadcare.com/base/ "HTTP/1.1 200 OK"
#  39%|███▉      | 7/18 [00:39<01:02,  5.67s/it]HTTP Request: POST https://upload.uploadcare.com/base/ "HTTP/1.1 200 OK"
# >> TRIGGERING GARBAGE COLLECTION.
# >> MEMORY CLEANER PROCESS NOT FOUND OR CANNOT BE EXECUTED. ENSURE 'WinMemoryCleaner.exe' IS PRESENT IN COMFYUI ROOT FOLDER.
#
# >> LOOP [ 101 ] CLOSE
#
# >> LOOP [ 101 ] ITERATION: 1
# VARS= {'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 1, 'finished': False, 'last_id': '100.0.0.101', 'data': 0, 'aux': 'https://ucarecdn.com/7864645a-3613-4a3e-a7d8-899be167785c/', 'index_override': 1, 'original_id': '101', 'unique_id': '100.0.0.101'}
#
# >> DATA MONITOR [ 100 ]
# TEXT:  %aux%['index']
# PASSTHROUGH:  <class 'NoneType'> None
# AUX INPUTS:  [{'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 1, 'finished': False, 'last_id': '100.0.0.101', 'data': 0, 'aux': 'https://ucarecdn.com/7864645a-3613-4a3e-a7d8-899be167785c/', 'index_override': 1, 'original_id': '101', 'unique_id': '100.0.0.101', 'condition_open': True}, None, None, None, None]
# PREV: {'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 1, 'finished': False, 'last_id': '100.0.0.101', 'data': 0, 'aux': 'https://ucarecdn.com/c4922438-c7d0-47fa-aa52-acf9b87216b6/', 'index_override': 1, 'original_id': '101', 'unique_id': '100.0.0.101', 'condition_open': True}['index']
# OUTPUT TYPE:  FORMULA
# REPLACING '%aux%' in '%aux%['index']' with '{'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 1, 'finished': False, 'last_id': '100.0.0.101', 'data': 0, 'aux': 'https://ucarecdn.com/7864645a-3613-4a3e-a7d8-899be167785c/', 'index_override': 1, 'original_id': '101', 'unique_id': '100.0.0.101', 'condition_open': True}'!
# >> PROCESSED TEXT AFTER VARIABLE REPLACEMENT: '{'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 1, 'finished': False, 'last_id': '100.0.0.101', 'data': 0, 'aux': 'https://ucarecdn.com/7864645a-3613-4a3e-a7d8-899be167785c/', 'index_override': 1, 'original_id': '101', 'unique_id': '100.0.0.101', 'condition_open': True}['index']'
# RETURN [TEXT]: 1
# Requested to load SDXLClipModel
# Loading 1 new model
# loaded completely 0.0 1560.802734375 True
#  44%|████▍     | 8/18 [00:45<00:56,  5.68s/it]Requested to load SDXL
# Loading 1 new model
# loaded completely 0.0 4897.0483474731445 True
# 100%|██████████| 15/15 [00:25<00:00,  1.67s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# loaded completely 0.0 319.11416244506836 True
#  83%|████████▎ | 15/18 [01:17<00:13,  4.57s/it]
# INFO: InsightFace detection resolution lowered to (512, 512).
# Requested to load SDXL
# Requested to load ControlNet
# Requested to load ControlNet
# Loading 3 new models
# loaded completely 9.5367431640625e+25 4897.0483474731445 True
# loaded completely 0.0 2396.797637939453 True
# loaded completely 0.0 2386.120147705078 True
# 100%|██████████| 18/18 [01:30<00:00,  5.05s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# loaded completely 0.0 319.11416244506836 True
#  28%|██▊       | 5/18 [00:33<01:27,  6.73s/it]
# WAS Node Suite: Image file saved to: /kaggle/working/ComfyUI/output/InstantID 2024-11-20-12-44-18_0001.jpeg
# WAS Node Suite: Image file saved to: /kaggle/working/ComfyUI/output/InstantID 2024-11-20-12-44-18_0002.jpeg
# WAS Node Suite: Image file saved to: /kaggle/working/ComfyUI/output/InstantID 2024-11-20-12-44-18_0003.jpeg
# WAS Node Suite: Image file saved to: /kaggle/working/ComfyUI/output/InstantID 2024-11-20-12-44-18_0004.jpeg
# HTTP Request: POST https://upload.uploadcare.com/base/ "HTTP/1.1 200 OK"
# HTTP Request: POST https://upload.uploadcare.com/base/ "HTTP/1.1 200 OK"
# HTTP Request: POST https://upload.uploadcare.com/base/ "HTTP/1.1 200 OK"
#  33%|███▎      | 6/18 [00:40<01:20,  6.70s/it]HTTP Request: POST https://upload.uploadcare.com/base/ "HTTP/1.1 200 OK"
# >> TRIGGERING GARBAGE COLLECTION.
# >> MEMORY CLEANER PROCESS NOT FOUND OR CANNOT BE EXECUTED. ENSURE 'WinMemoryCleaner.exe' IS PRESENT IN COMFYUI ROOT FOLDER.
#
# >> LOOP [ 101 ] CLOSE
#
# >> LOOP [ 101 ] ITERATION: 1
# VARS= {'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 1, 'finished': False, 'last_id': '100.0.0.101', 'data': 0, 'aux': 'https://ucarecdn.com/3443ca38-76f9-4a1f-acc4-ae5cbd7b8850/', 'index_override': 1, 'original_id': '101', 'unique_id': '100.0.0.101'}
#
# >> DATA MONITOR [ 100 ]
# TEXT:  %aux%['index']
# PASSTHROUGH:  <class 'NoneType'> None
# AUX INPUTS:  [{'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 1, 'finished': False, 'last_id': '100.0.0.101', 'data': 0, 'aux': 'https://ucarecdn.com/3443ca38-76f9-4a1f-acc4-ae5cbd7b8850/', 'index_override': 1, 'original_id': '101', 'unique_id': '100.0.0.101', 'condition_open': True}, None, None, None, None]
# PREV: {'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 1, 'finished': False, 'last_id': '100.0.0.101', 'data': 0, 'aux': 'https://ucarecdn.com/10733205-491d-4618-aadd-136422f8bdaf/', 'index_override': 1, 'original_id': '101', 'unique_id': '100.0.0.101', 'condition_open': True}['index']
# OUTPUT TYPE:  FORMULA
# REPLACING '%aux%' in '%aux%['index']' with '{'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 1, 'finished': False, 'last_id': '100.0.0.101', 'data': 0, 'aux': 'https://ucarecdn.com/3443ca38-76f9-4a1f-acc4-ae5cbd7b8850/', 'index_override': 1, 'original_id': '101', 'unique_id': '100.0.0.101', 'condition_open': True}'!
# >> PROCESSED TEXT AFTER VARIABLE REPLACEMENT: '{'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 1, 'finished': False, 'last_id': '100.0.0.101', 'data': 0, 'aux': 'https://ucarecdn.com/3443ca38-76f9-4a1f-acc4-ae5cbd7b8850/', 'index_override': 1, 'original_id': '101', 'unique_id': '100.0.0.101', 'condition_open': True}['index']'
# RETURN [TEXT]: 1
# Requested to load SDXLClipModel
# Loading 1 new model
# loaded completely 0.0 1560.802734375 True
# Requested to load SDXL
# Loading 1 new model
# loaded completely 0.0 4897.0483474731445 True
# 100%|██████████| 15/15 [00:21<00:00,  1.41s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# loaded completely 0.0 319.11416244506836 True
#  61%|██████    | 11/18 [01:10<00:41,  5.92s/it]
# INFO: InsightFace detection resolution lowered to (512, 512).
#  67%|██████▋   | 12/18 [01:16<00:34,  5.70s/it]Requested to load ControlNet
# Requested to load SDXL
# Requested to load ControlNet
# Loading 3 new models
# loaded completely 0.0 2386.120147705078 True
# loaded completely 9.5367431640625e+25 4897.0483474731445 True
# loaded completely 0.0 2396.797637939453 True
# 100%|██████████| 18/18 [01:47<00:00,  5.97s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# loaded completely 0.0 319.11416244506836 True
#  61%|██████    | 11/18 [00:59<00:35,  5.02s/it]
# WAS Node Suite: Image file saved to: /kaggle/working/ComfyUI/output/InstantID 2024-11-20-12-46-00_0001.jpeg
# WAS Node Suite: Image file saved to: /kaggle/working/ComfyUI/output/InstantID 2024-11-20-12-46-00_0002.jpeg
# WAS Node Suite: Image file saved to: /kaggle/working/ComfyUI/output/InstantID 2024-11-20-12-46-00_0003.jpeg
# WAS Node Suite: Image file saved to: /kaggle/working/ComfyUI/output/InstantID 2024-11-20-12-46-00_0004.jpeg
# HTTP Request: POST https://upload.uploadcare.com/base/ "HTTP/1.1 200 OK"
# HTTP Request: POST https://upload.uploadcare.com/base/ "HTTP/1.1 200 OK"
#  67%|██████▋   | 12/18 [01:04<00:29,  4.84s/it]HTTP Request: POST https://upload.uploadcare.com/base/ "HTTP/1.1 200 OK"
# HTTP Request: POST https://upload.uploadcare.com/base/ "HTTP/1.1 200 OK"
# >> JOINING PRIMITIVE ' input2 ' INTO BATCH!
#
# >> LOOP [ 101 ] CLOSE
#
# >> LOOP [ 101 ] ITERATION: 2
# VARS= {'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 2, 'finished': False, 'last_id': '100.0.0.R.0.0.100.0.0.101', 'data': 0, 'aux': ('https://ucarecdn.com/7864645a-3613-4a3e-a7d8-899be167785c/', 'https://ucarecdn.com/267b38c6-6b1c-4ce7-bee9-8ffa6759ca60/'), 'index_override': 2, 'original_id': '101', 'unique_id': '100.0.0.R.0.0.100.0.0.101'}
#
# >> DATA MONITOR [ 100 ]
# TEXT:  %aux%['index']
# PASSTHROUGH:  <class 'NoneType'> None
# AUX INPUTS:  [{'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 2, 'finished': False, 'last_id': '100.0.0.R.0.0.100.0.0.101', 'data': 0, 'aux': ('https://ucarecdn.com/7864645a-3613-4a3e-a7d8-899be167785c/', 'https://ucarecdn.com/267b38c6-6b1c-4ce7-bee9-8ffa6759ca60/'), 'index_override': 2, 'original_id': '101', 'unique_id': '100.0.0.R.0.0.100.0.0.101', 'condition_open': True}, None, None, None, None]
# PREV: {'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 2, 'finished': False, 'last_id': '100.0.0.R.0.0.100.0.0.101', 'data': 0, 'aux': ('https://ucarecdn.com/c4922438-c7d0-47fa-aa52-acf9b87216b6/', 'https://ucarecdn.com/de6c03fe-6b68-4c64-a8ac-59ec72f468c7/'), 'index_override': 2, 'original_id': '101', 'unique_id': '100.0.0.R.0.0.100.0.0.101', 'condition_open': True}['index']
# OUTPUT TYPE:  FORMULA
# REPLACING '%aux%' in '%aux%['index']' with '{'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 2, 'finished': False, 'last_id': '100.0.0.R.0.0.100.0.0.101', 'data': 0, 'aux': ('https://ucarecdn.com/7864645a-3613-4a3e-a7d8-899be167785c/', 'https://ucarecdn.com/267b38c6-6b1c-4ce7-bee9-8ffa6759ca60/'), 'index_override': 2, 'original_id': '101', 'unique_id': '100.0.0.R.0.0.100.0.0.101', 'condition_open': True}'!
# >> PROCESSED TEXT AFTER VARIABLE REPLACEMENT: '{'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 2, 'finished': False, 'last_id': '100.0.0.R.0.0.100.0.0.101', 'data': 0, 'aux': ('https://ucarecdn.com/7864645a-3613-4a3e-a7d8-899be167785c/', 'https://ucarecdn.com/267b38c6-6b1c-4ce7-bee9-8ffa6759ca60/'), 'index_override': 2, 'original_id': '101', 'unique_id': '100.0.0.R.0.0.100.0.0.101', 'condition_open': True}['index']'
# RETURN [TEXT]: 2
#  72%|███████▏  | 13/18 [01:08<00:23,  4.71s/it]Requested to load SDXLClipModel
# Loading 1 new model
# loaded completely 0.0 1560.802734375 True
# Requested to load SDXL
# Loading 1 new model
# loaded completely 9.5367431640625e+25 4897.0483474731445 True
# 100%|██████████| 18/18 [01:30<00:00,  5.05s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# loaded completely 0.0 319.11416244506836 True
# 100%|██████████| 15/15 [00:25<00:00,  1.68s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# loaded completely 0.0 319.11416244506836 True
# INFO: InsightFace detection resolution lowered to (512, 512).
# Requested to load ControlNet
# Requested to load ControlNet
# Requested to load SDXL
# Loading 3 new models
# loaded completely 0.0 2386.120147705078 True
# loaded completely 0.0 2396.797637939453 True
# loaded completely 9.5367431640625e+25 4897.0483474731445 True
#   6%|▌         | 1/18 [00:06<01:54,  6.73s/it]
# WAS Node Suite: Image file saved to: /kaggle/working/ComfyUI/output/InstantID 2024-11-20-12-46-57_0001.jpeg
# WAS Node Suite: Image file saved to: /kaggle/working/ComfyUI/output/InstantID 2024-11-20-12-46-57_0002.jpeg
# WAS Node Suite: Image file saved to: /kaggle/working/ComfyUI/output/InstantID 2024-11-20-12-46-57_0003.jpeg
# WAS Node Suite: Image file saved to: /kaggle/working/ComfyUI/output/InstantID 2024-11-20-12-46-57_0004.jpeg
#  11%|█         | 2/18 [00:13<01:47,  6.73s/it]HTTP Request: POST https://upload.uploadcare.com/base/ "HTTP/1.1 200 OK"
# HTTP Request: POST https://upload.uploadcare.com/base/ "HTTP/1.1 200 OK"
# HTTP Request: POST https://upload.uploadcare.com/base/ "HTTP/1.1 200 OK"
# HTTP Request: POST https://upload.uploadcare.com/base/ "HTTP/1.1 200 OK"
# >> JOINING PRIMITIVE ' input2 ' INTO BATCH!
#
# >> LOOP [ 101 ] CLOSE
#
# >> LOOP [ 101 ] ITERATION: 2
# VARS= {'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 2, 'finished': False, 'last_id': '100.0.0.R.0.0.100.0.0.101', 'data': 0, 'aux': ('https://ucarecdn.com/3443ca38-76f9-4a1f-acc4-ae5cbd7b8850/', 'https://ucarecdn.com/2f269d5c-03bd-490f-be0a-828a9480d1bf/'), 'index_override': 2, 'original_id': '101', 'unique_id': '100.0.0.R.0.0.100.0.0.101'}
#
# >> DATA MONITOR [ 100 ]
# TEXT:  %aux%['index']
# PASSTHROUGH:  <class 'NoneType'> None
# AUX INPUTS:  [{'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 2, 'finished': False, 'last_id': '100.0.0.R.0.0.100.0.0.101', 'data': 0, 'aux': ('https://ucarecdn.com/3443ca38-76f9-4a1f-acc4-ae5cbd7b8850/', 'https://ucarecdn.com/2f269d5c-03bd-490f-be0a-828a9480d1bf/'), 'index_override': 2, 'original_id': '101', 'unique_id': '100.0.0.R.0.0.100.0.0.101', 'condition_open': True}, None, None, None, None]
# PREV: {'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 2, 'finished': False, 'last_id': '100.0.0.R.0.0.100.0.0.101', 'data': 0, 'aux': ('https://ucarecdn.com/10733205-491d-4618-aadd-136422f8bdaf/', 'https://ucarecdn.com/d084f52c-8af9-4903-a494-ee63bbb536d4/'), 'index_override': 2, 'original_id': '101', 'unique_id': '100.0.0.R.0.0.100.0.0.101', 'condition_open': True}['index']
# OUTPUT TYPE:  FORMULA
# REPLACING '%aux%' in '%aux%['index']' with '{'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 2, 'finished': False, 'last_id': '100.0.0.R.0.0.100.0.0.101', 'data': 0, 'aux': ('https://ucarecdn.com/3443ca38-76f9-4a1f-acc4-ae5cbd7b8850/', 'https://ucarecdn.com/2f269d5c-03bd-490f-be0a-828a9480d1bf/'), 'index_override': 2, 'original_id': '101', 'unique_id': '100.0.0.R.0.0.100.0.0.101', 'condition_open': True}'!
# >> PROCESSED TEXT AFTER VARIABLE REPLACEMENT: '{'id': '101', 'start': 0, 'end': 4, 'step': 1, 'index': 2, 'finished': False, 'last_id': '100.0.0.R.0.0.100.0.0.101', 'data': 0, 'aux': ('https://ucarecdn.com/3443ca38-76f9-4a1f-acc4-ae5cbd7b8850/', 'https://ucarecdn.com/2f269d5c-03bd-490f-be0a-828a9480d1bf/'), 'index_override': 2, 'original_id': '101', 'unique_id': '100.0.0.R.0.0.100.0.0.101', 'condition_open': True}['index']'
# RETURN [TEXT]: 2
# Requested to load SDXLClipModel
# Loading 1 new model
#  17%|█▋        | 3/18 [00:20<01:41,  6.75s/it]loaded completely 0.0 1560.802734375 True
# Requested to load SDXL
# Loading 1 new model
# loaded completely 9.5367431640625e+25 4897.0483474731445 True
# 100%|██████████| 15/15 [00:20<00:00,  1.40s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# loaded completely 0.0 319.11416244506836 True
#  39%|███▉      | 7/18 [00:47<01:14,  6.75s/it]
# INFO: InsightFace detection resolution lowered to (512, 512).
# Requested to load ControlNet
# Requested to load ControlNet
# Requested to load SDXL
# Loading 3 new models
# loaded completely 0.0 2386.120147705078 True
# loaded completely 0.0 2396.797637939453 True
# loaded completely 9.5367431640625e+25 4897.0483474731445 True
# 100%|██████████| 18/18 [01:47<00:00,  5.96s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# loaded completely 0.0 319.11416244506836 True
#  72%|███████▏  | 13/18 [01:09<00:23,  4.71s/it]

# %%
def iframe_thread(port):
  while True:
      time.sleep(0.5)
      sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
      result = sock.connect_ex(('127.0.0.1', port))
      if result == 0:
        break
      sock.close()
  print("\nComfyUI finished loading, trying to launch localtunnel (if it gets stuck here localtunnel is having issues)\n")

  print("The password/enpoint ip for localtunnel is:", urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip("\n"))
#   p = subprocess.Popen(["lt", "--port", "{}".format(port)], stdout=subprocess.PIPE)
  command = f"nohup lt --port {port} --print-requests >> nohup{port}.out 2>&1 & echo $!"
  p = subprocess.Popen(command, shell=True, stdout=subprocess.PIPE)
  
  for line in p.stdout:
    print(line.decode(), end='')


# threading.Thread(target=iframe_thread, daemon=True, args=(8188,8189,)).start()
# %cd /kaggle/working/ComfyUI/
# # threading.Thread(target=iframe_thread, daemon=True, args=(8189,)).start()
# !python main.py  --cuda-device 0 --port 8188; python main.py --cuda-device 1 --port 8189
# # --dont-print-server

# %%
# Start threads for both ports
xT1 =threading.Thread(target=iframe_thread, daemon=True, args=(8188,))
xT1.start()
xT2 = threading.Thread(target=iframe_thread, daemon=True, args=(8189,)) #.start()
xT2.start()

# %% [markdown]
# <span style="background-color: #add8e6; color: #8b0000; padding: 5px;">
#   <font size=18px>HERE PS.
# </span>

# %%
# !ps fax

# %%
# !kill 1220 1331 1343 1353 1368 1169 1206 1074

# %%
# !wget -q https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
# !dpkg -i cloudflared-linux-amd64.deb

import subprocess
import threading
import time

# %%
xport=  8188
command = f"nohup cloudflared tunnel --url http://localhost:{xport} >> nohup{xport}.out 2>&1 & echo $!"
p = subprocess.Popen(command, shell=True, stdout=subprocess.PIPE)
  
for line in p.stdout:
    print(line.decode(), end='')

# %%
import subprocess
subprocess.Popen(["cloudflared", "tunnel", '--url', f'http://localhost:8188',]) #"run", "my-tunnel"])

# %%
# !ps fax

# %%
import subprocess
subprocess.Popen(["cloudflared", "tunnel", '--url', f'http://localhost:8189',]) #"run", "my-tunnel"])

# %%
# !ps fax

# %% [raw]
# !uv pip install --system cloudflared

# %% [raw]
# from cloudflared import CloudFlare
# CloudFlare.subprocess()

# %%
# !uv pip install --system -q pyngrok
# !ngrok authtoken "2f3dIfgJffUXDkLfUJ4V0PBrdln_74tALZeMqwobwcbyupmuw"

# %%
from pyngrok import ngrok
public_url = ngrok.connect('localhost:8188')
print(f"Please click on the text below {public_url}")

# %%
from pyngrok import ngrok
public_url = ngrok.connect('localhost:8189')
print(f"Please click on the text below {public_url}")

# %%
# !wget -q https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
# !dpkg -i cloudflared-linux-amd64.deb

import subprocess
import threading
import time

# %%
def start_tunnel(xport=8188):
    tunnel_process = subprocess.Popen(
        ['cloudflared', 'tunnel', '--url', f'http://localhost:{xport}'],
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT,
        universal_newlines=True
    )
    
    # Look for the tunnel URL in the output
    while True:
        output = tunnel_process.stdout.readline()
        if output:
            if 'trycloudflare.com' in output:
                # Extract and display the URL
                url = output.split('|')[3].strip()
                print(f"ComfyUI is available at: {url}")
                break

# Start the tunnel in a separate thread
# tunnel_thread = threading.Thread(target=start_tunnel,args=(8188,), daemon=True)
# tunnel_thread.start()

xP1 = subprocess.Popen(["python", "main.py", "--cuda-device", "0", "--port", "8188","--highvram"])
time.sleep(30)
# Wait a moment for the tunnel to establish
time.sleep(5)

# %%
# !ps fax

# %% [raw]
# !wget https://huggingface.co/guozinan/PuLID/resolve/main/pulid_flux_v0.9.0.safetensors

# %%
# %pip install -U pip uv -q
# !uv venv
# !source .venv/bin/activate
# !uv pip install --system  --quiet pyngrok #--system
# !uv pip install --system --no-deps --quiet protobuf==3.20.*   #==4.21.12
# !uv pip install  --system --no-deps --quiet validators
# !ngrok authtoken "2f3dIfgJffUXDkLfUJ4V0PBrdln_74tALZeMqwobwcbyupmuw"

# %%
# !uv  pip install   --system  -q omegaconf accelerate einops transformers>=4.28.1 safetensors>=0.4.2 aiohttp pyyaml Pillow scipy tqdm psutil tokenizers>=0.13.3
# !uv pip install  --system -q torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121 ultralytics insightface bitsandbytes
# !uv pip install  --system -q torchsde

# %%
# Change directory to ComfyUI
os.chdir("/kaggle/working/ComfyUI/")

# Launch ComfyUI instances
xP1 = subprocess.Popen(["python", "main.py", "--cuda-device", "0", "--port", "8188","--highvram"])
time.sleep(30)

xP2= subprocess.Popen(["python", "main.py", "--cuda-device", "1", "--port", "8189","--highvram"])
time.sleep(30)
# subprocess.Popen(["./limit_ram.sh","python", "main.py", "--cuda-device", "0", "--port", "8188"])
# subprocess.Popen(["./limit_ram.sh","python", "main.py", "--cuda-device", "1", "--port", "8189"])

# time.sleep(30)

# %%
# !ps fax

# %%
from pyngrok import ngrok
# import ngrok

# listener = ngrok.forward("localhost:8080", authtoken_from_env=True)

# print(f"Ingress established at: {listener.url()}");


public_url = ngrok.connect('localhost:8188')
print(f"Please click on the text below {public_url}")

# %%
from pyngrok import ngrok
public_url = ngrok.connect('localhost:8189')
print(f"Please click on the text below {public_url}")

# %%
# !ps fax

# %%
# !ls -ltrah /kaggle/working/ComfyUI/models/clip_vision

# %%
# !rm /kaggle/working/ComfyUI/models/clip_vision/clip-vit-large-patch14.safetensors

# %%
# !sudo apt install ncdu
# !kill 659 701

# %%
# !du -h /kaggle/working/ComfyUI/models/

# %%
# !du -h /kaggle/working/ComfyUI/models/clip/t5

# %%
# !ls -ltrah /kaggle/working/ComfyUI/models/clip/t5

# %%
def iframe_thread(port):
  while True:
      time.sleep(0.5)
      sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
      result = sock.connect_ex(('127.0.0.1', port))
      if result == 0:
        break
      sock.close()
  print("\nComfyUI finished loading, trying to launch localtunnel (if it gets stuck here localtunnel is having issues)\n")

  print("The password/enpoint ip for localtunnel is:", urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip("\n"))
  p = subprocess.Popen(["lt", "--port", "{}".format(port)], stdout=subprocess.PIPE)
  command = f"nohup lt --port {port} --print-requests >> nohup{port}.out 2>&1 & echo $!"
  p = subprocess.Popen(command, shell=True, stdout=subprocess.PIPE)
  
  for line in p.stdout:
    print(line.decode(), end='')


# threading.Thread(target=iframe_thread, daemon=True, args=(8188,8189,)).start()
# %cd /kaggle/working/ComfyUI/
# # threading.Thread(target=iframe_thread, daemon=True, args=(8189,)).start()
# !python main.py  --cuda-device 0 --port 8188; python main.py --cuda-device 1 --port 8189
# # --dont-print-server

# %%
# %pip install uv

# %% [raw]
# !uv pip --help

# %%
# Start threads for both ports
xT1 =threading.Thread(target=iframe_thread, daemon=True, args=(8188,))
xT1.start()
xT2 = threading.Thread(target=iframe_thread, daemon=True, args=(8189,)) #.start()
xT2.start()

# %%
subprocess.run("tail -f nohup8188.out &",shell=True)

# %%
subprocess.run("tail -f nohup8189.out &",shell=True)

# %%
# !ps fax

# %%
# !kill 679  682

# %%
# !kill 929 930 931

# %%
xT1 =threading.Thread(target=iframe_thread, daemon=True, args=(8188,))
xT1.start()

# %%
import subprocess
import time

def run_cloudflare_tunnel(hostname, local_url):
    cmd = f"cloudflared tunnel --url {local_url} {hostname}"
    process = subprocess.Popen(cmd, shell=True)
    return process

# Configuration
hostname = "kaggle.com"
local_url = "http://localhost:8000"

# Start the tunnel
tunnel_process = run_cloudflare_tunnel(hostname, local_url)

print(f"Tunnel started. Forwarding {hostname} to {local_url}")
print("Press Ctrl+C to stop the tunnel.")

try:
    # Keep the script running
    while True:
        time.sleep(1)
except KeyboardInterrupt:
    print("Stopping the tunnel...")
    tunnel_process.terminate()
    print("Tunnel stopped.")

# %%
# !ps fax

# %%
# Start threads for both ports
# xT1 =threading.Thread(target=iframe_thread, daemon=True, args=(8188,))
# xT1.start()
threading.Thread(target=iframe_thread, daemon=True, args=(8188,)).start()
# xT2 = threading.Thread(target=iframe_thread, daemon=True, args=(8189,)) #.start()
# xT2.start()

# %%
xP1.kill()
xP2.kill()

# %%
xT1._delete()

# %%
xT2=xT2.run()

# %%
I solved it with code-server and pyngrok

    Install Code-server

# !curl -fsSL https://code-server.dev/install.sh | sh

    Install pyngrok & get the tunnel URL (you can't run background process in kaggle)

# !pip install pyngrok

    Input ngrok auth token and get tunnel http 80.

from pyngrok import conf, ngrok

conf.get_default().auth_token = "<YOUR TOKEN>"

http_tunnel = ngrok.connect()
ssh_tunnel = ngrok.connect(80, "http")

    Get the tunnel URL

from pyngrok import ngrok

# [<NgrokTunnel: "http://<public_sub>.ngrok.io" -> "http://localhost:80">]
tunnels = ngrok.get_tunnels()
tunnels

    Get code-server default password

# !cat  ~/.config/code-server/config.yaml

    run code-server

# !code-server --port 80

Hopefully this workaround will work for a while.

# %%
# !ps fax

# %%
# !curl https://loca.lt/mytunnelpassword

# %%
# !curl https://loca.lt/

# %%
 # !wget -q -O - https://loca.lt/mytunnelpassword

# %%
# !kill 4103 4104 4102

# %%
# %%writefile /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager/config.ini
# [default]
# preview_method = none
# badge_mode = none
# git_exe =
# channel_url = https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main
# share_option = all
# bypass_ssl = False
# file_logging = True
# default_ui = none
# component_policy = workflow
# double_click_policy = copy-all
# windows_selector_event_loop_policy = False
# model_download_by_agent = True
# downgrade_blacklist =
# security_level = normal-

# %%
# !du -hd1 /kaggle/working/

# %%
# !du -hd1 /kaggle/working/ComfyUI | sort -rh

# %%
# !du -hd1 /kaggle/working/ComfyUI/models | sort -rh

# %%
# !rm /kaggle/working/ComfyUI/.venv -r
