# %%
import os
import zipfile
from datetime import datetime

def zip_folder(folder_path, zip_path):
    with zipfile.ZipFile(zip_path, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for root, _, files in os.walk(folder_path):
            for file in files:
                file_path = os.path.join(root, file)
                arcname = os.path.relpath(file_path, folder_path)
                zipf.write(file_path, arcname)

# %%
# Example usage
folder_to_zip = '/kaggle/working/ComfyUI/output'
output_zip = f'/kaggle/working/output_{datetime.now():%d%m%Y_%H%M}.zip'
# zip_folder(folder_to_zip, output_zip)

# %%
import shutil
shutil.make_archive(output_zip, 'zip', folder_to_zip)
# Out:
# '/kaggle/working/output_09092024_1437.zip.zip'

# %% [raw]
# # Example usage
# folder_to_zip = '/kaggle/working/ComfyUI/output'
# output_zip = f'/kaggle/working/output_{datetime.now():%d%m%Y_%H%M}.zip'
# # zip_folder(folder_to_zip, output_zip)

# %%
import shutil
x_old = '/kaggle/working/old_output'
os.makedirs(x_old,exist_ok=True)
for x in os.listdir(folder_to_zip):
    try:
        shutil.move(folder_to_zip +'/' + x, x_old)
    except:
        print("Fichier deja existant??")
# Out:
# Fichier deja existant??
# Fichier deja existant??
# Fichier deja existant??
# Fichier deja existant??
# Fichier deja existant??
# Fichier deja existant??
# Fichier deja existant??
# Fichier deja existant??
# Fichier deja existant??
# Fichier deja existant??
# Fichier deja existant??
# Fichier deja existant??
# Fichier deja existant??
# Fichier deja existant??
# Fichier deja existant??
# Fichier deja existant??
# Fichier deja existant??
# Fichier deja existant??
# Fichier deja existant??
# Fichier deja existant??
# Fichier deja existant??
# Fichier deja existant??
# Fichier deja existant??
# Fichier deja existant??

# %%
get_ipython().system("rm /kaggle/working/old_output -R")

# %%
def install_this(xthe_url):
    print("install ",xthe_url)
    # %cd /kaggle/working/ComfyUI/custom_nodes
    get_ipython().system(f'git clone {xthe_url}')
    xfolder =  xthe_url.split('/')[-1].rstrip('.git')
    print(f"{xfolder=}")
    # %cd /kaggle/working/ComfyUI/custom_nodes/$xfolder
    get_ipython().system('git pull --all')
    if os.path.exists("requirements.txt"):
        # %pip install -r requirements.txt --quiet
#     else :
#         %pip install --quiet
    print("DONE install ",xthe_url)

# %%
update = True

from os import path

# %cd /kaggle/working
# !git clone https://github.com/comfyanonymous/ComfyUI.git
# %cd ComfyUI
if update:
    get_ipython().system('git pull --all')
# !pip install -r requirements.txt --quiet

checkpoints =  '/kaggle/working/ComfyUI/models/checkpoints'
link_path = checkpoints + '/temp-models'
temp_models = '/kaggle/temp/temp-models'

# !mkdir /kaggle/temp
# !mkdir $temp_models

if not path.exists(link_path):
    get_ipython().system(f'ln -s {temp_models} {checkpoints}')

# !mamba install openssh -y --quiet

# Install the node manager
update_manager = True
install_this("https://github.com/ltdrdata/ComfyUI-Manager")
# Was node
install_this('https://github.com/WASasquatch/was-node-suite-comfyui')
# Rgthree
install_this("https://github.com/rgthree/rgthree-comfy")
# REactor
install_this("https://github.com/Gourieff/comfyui-reactor-node")
# Comfyui noise
install_this("https://github.com/BlenderNeko/ComfyUI_Noise")
# Comfyui impact
install_this("https://github.com/ltdrdata/ComfyUI-Impact-Pack")
# pythongossss
install_this("https://github.com/pythongosssss/ComfyUI-Custom-Scripts")
# Comfyui easy use
install_this("https://github.com/yolain/ComfyUI-Easy-Use")
# KJNODES
install_this("https://github.com/kijai/ComfyUI-KJNodes")
# Out:
# /kaggle/working
# fatal: destination path 'ComfyUI' already exists and is not an empty directory.
# /kaggle/working/ComfyUI
# Fetching origin
# remote: Enumerating objects: 334, done.
# remote: Counting objects: 100% (240/240), done.
# remote: Compressing objects: 100% (125/125), done.
# remote: Total 334 (delta 159), reused 157 (delta 114), pack-reused 94 (from 1)
# Receiving objects: 100% (334/334), 7.07 MiB | 15.29 MiB/s, done.
# Resolving deltas: 100% (162/162), completed with 14 local objects.
# From https://github.com/comfyanonymous/ComfyUI
#    b33cd61..cd49553  master           -> origin/master
#  * [new branch]      rh-expand        -> origin/rh-expand
#  * [new branch]      rh-userdirectory -> origin/rh-userdirectory
#  * [new tag]         v0.2.0           -> v0.2.0
#  * [new tag]         v0.2.1           -> v0.2.1
#  * [new tag]         v0.2.2           -> v0.2.2
# Updating b33cd61..cd49553
# error: Your local changes to the following files would be overwritten by merge:
# 	.ci/windows_base_files/README_VERY_IMPORTANT.txt
# Please commit your changes or stash them before you merge.
# Aborting
# warning  libmamba Cache file "/opt/conda/pkgs/cache/c6f2354e.json" was modified by another program
# warning  libmamba Cache file "/opt/conda/pkgs/cache/86b0f08d.json" was modified by another program
# warning  libmamba Cache file "/opt/conda/pkgs/cache/c9ddbd6b.json" was modified by another program
# warning  libmamba Cache file "/opt/conda/pkgs/cache/b121c3e7.json" was modified by another program
# warning  libmamba Cache file "/opt/conda/pkgs/cache/d4808d92.json" was modified by another program
# warning  libmamba Cache file "/opt/conda/pkgs/cache/223a346e.json" was modified by another program
# warning  libmamba Cache file "/opt/conda/pkgs/cache/497deca9.json" was modified by another program
# warning  libmamba Cache file "/opt/conda/pkgs/cache/09cdf8bf.json" was modified by another program
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# install  https://github.com/ltdrdata/ComfyUI-Manager
# /kaggle/working/ComfyUI/custom_nodes
# fatal: destination path 'ComfyUI-Manager' already exists and is not an empty directory.
# xfolder='ComfyUI-Manager'
# /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager
# Fetching origin
# remote: Enumerating objects: 265, done.
# remote: Counting objects: 100% (114/114), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 265 (delta 94), reused 91 (delta 89), pack-reused 151 (from 1)
# Receiving objects: 100% (265/265), 1.03 MiB | 16.01 MiB/s, done.
# Resolving deltas: 100% (187/187), completed with 12 local objects.
# From https://github.com/ltdrdata/ComfyUI-Manager
#    d4812c0..ce874d5  main       -> origin/main
#    ad1faee..a1c90ce  feat/cnr   -> origin/feat/cnr
# Updating d4812c0..ce874d5
# Fast-forward
#  custom-node-list.json                |  475 +++-
#  extension-node-map.json              |  749 +++++-
#  github-stats.json                    | 4382 ++++++++++++++++++----------------
#  glob/manager_core.py                 |    2 +-
#  js/comfyui-manager.js                |    4 +-
#  js/comfyui-share-common.js           |   26 +-
#  js/comfyui-share-openart.js          |    4 +-
#  js/terminal.js                       |    4 +-
#  node_db/dev/custom-node-list.json    |  183 +-
#  node_db/dev/extension-node-map.json  |  183 +-
#  node_db/dev/github-stats.json        |  727 +++---
#  node_db/legacy/custom-node-list.json |   30 +
#  node_db/new/custom-node-list.json    |  720 +++---
#  node_db/new/extension-node-map.json  |  749 +++++-
#  pyproject.toml                       |    2 +-
#  15 files changed, 5156 insertions(+), 3084 deletions(-)
# Note: you may need to restart the kernel to use updated packages.
# DONE install  https://github.com/ltdrdata/ComfyUI-Manager
# install  https://github.com/WASasquatch/was-node-suite-comfyui
# /kaggle/working/ComfyUI/custom_nodes
# Cloning into 'was-node-suite-comfyui'...
# remote: Enumerating objects: 2284, done.
# remote: Counting objects: 100% (832/832), done.
# remote: Compressing objects: 100% (133/133), done.
# remote: Total 2284 (delta 780), reused 699 (delta 699), pack-reused 1452 (from 1)
# Receiving objects: 100% (2284/2284), 39.43 MiB | 38.24 MiB/s, done.
# Resolving deltas: 100% (1398/1398), done.
# xfolder='was-node-suite-comfyu'
# [Errno 2] No such file or directory: '/kaggle/working/ComfyUI/custom_nodes/was-node-suite-comfyu'
# /kaggle/working/ComfyUI/custom_nodes
# Fetching origin
# Updating b33cd61..cd49553
# error: Your local changes to the following files would be overwritten by merge:
# 	.ci/windows_base_files/README_VERY_IMPORTANT.txt
# Please commit your changes or stash them before you merge.
# Aborting
# DONE install  https://github.com/WASasquatch/was-node-suite-comfyui
# install  https://github.com/rgthree/rgthree-comfy
# /kaggle/working/ComfyUI/custom_nodes
# fatal: destination path 'rgthree-comfy' already exists and is not an empty directory.
# xfolder='rgthree-comfy'
# /kaggle/working/ComfyUI/custom_nodes/rgthree-comfy
# Fetching origin
# Already up to date.
# Note: you may need to restart the kernel to use updated packages.
# DONE install  https://github.com/rgthree/rgthree-comfy
# install  https://github.com/Gourieff/comfyui-reactor-node
# /kaggle/working/ComfyUI/custom_nodes
# fatal: destination path 'comfyui-reactor-node' already exists and is not an empty directory.
# xfolder='comfyui-reactor-node'
# /kaggle/working/ComfyUI/custom_nodes/comfyui-reactor-node
# Fetching origin
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 386 bytes | 386.00 KiB/s, done.
# From https://github.com/Gourieff/comfyui-reactor-node
#    2832357..983498b  main       -> origin/main
# Updating 2832357..983498b
# Fast-forward
#  scripts/reactor_version.py | 2 +-
#  1 file changed, 1 insertion(+), 1 deletion(-)
# Note: you may need to restart the kernel to use updated packages.
# DONE install  https://github.com/Gourieff/comfyui-reactor-node
# install  https://github.com/BlenderNeko/ComfyUI_Noise
# /kaggle/working/ComfyUI/custom_nodes
# Cloning into 'ComfyUI_Noise'...
# remote: Enumerating objects: 95, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 95 (delta 25), reused 25 (delta 25), pack-reused 65 (from 1)
# Receiving objects: 100% (95/95), 1.15 MiB | 27.49 MiB/s, done.
# Resolving deltas: 100% (54/54), done.
# xfolder='ComfyUI_Noise'
# /kaggle/working/ComfyUI/custom_nodes/ComfyUI_Noise
# Fetching origin
# Already up to date.
# DONE install  https://github.com/BlenderNeko/ComfyUI_Noise
# install  https://github.com/ltdrdata/ComfyUI-Impact-Pack
# /kaggle/working/ComfyUI/custom_nodes
# Cloning into 'ComfyUI-Impact-Pack'...
# remote: Enumerating objects: 4778, done.
# remote: Counting objects: 100% (1806/1806), done.
# remote: Compressing objects: 100% (343/343), done.
# remote: Total 4778 (delta 1582), reused 1658 (delta 1463), pack-reused 2972 (from 1)
# Receiving objects: 100% (4778/4778), 31.76 MiB | 51.21 MiB/s, done.
# Resolving deltas: 100% (3220/3220), done.
# xfolder='ComfyUI-Impact-Pack'
# /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Impact-Pack
# Fetching origin
# Already up to date.
# Note: you may need to restart the kernel to use updated packages.
# DONE install  https://github.com/ltdrdata/ComfyUI-Impact-Pack
# install  https://github.com/pythongosssss/ComfyUI-Custom-Scripts
# /kaggle/working/ComfyUI/custom_nodes
# Cloning into 'ComfyUI-Custom-Scripts'...
# remote: Enumerating objects: 2023, done.
# remote: Counting objects: 100% (718/718), done.
# remote: Compressing objects: 100% (182/182), done.
# remote: Total 2023 (delta 532), reused 620 (delta 491), pack-reused 1305 (from 1)
# Receiving objects: 100% (2023/2023), 508.55 KiB | 14.53 MiB/s, done.
# Resolving deltas: 100% (1185/1185), done.
# xfolder='ComfyUI-Custom-Scripts'
# /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Custom-Scripts
# Fetching origin
# Already up to date.
# DONE install  https://github.com/pythongosssss/ComfyUI-Custom-Scripts
# install  https://github.com/yolain/ComfyUI-Easy-Use
# /kaggle/working/ComfyUI/custom_nodes
# Cloning into 'ComfyUI-Easy-Use'...
# remote: Enumerating objects: 3109, done.
# remote: Counting objects: 100% (950/950), done.
# remote: Compressing objects: 100% (348/348), done.
# remote: Total 3109 (delta 668), reused 829 (delta 592), pack-reused 2159 (from 1)
# Receiving objects: 100% (3109/3109), 12.64 MiB | 38.18 MiB/s, done.
# Resolving deltas: 100% (2160/2160), done.
# xfolder='ComfyUI-Easy-Use'
# /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Easy-Use
# Fetching origin
# Already up to date.
# Note: you may need to restart the kernel to use updated packages.
# DONE install  https://github.com/yolain/ComfyUI-Easy-Use
# install  https://github.com/kijai/ComfyUI-KJNodes
# /kaggle/working/ComfyUI/custom_nodes
# Cloning into 'ComfyUI-KJNodes'...
# remote: Enumerating objects: 2048, done.
# remote: Counting objects: 100% (571/571), done.
# remote: Compressing objects: 100% (106/106), done.
# remote: Total 2048 (delta 492), reused 519 (delta 465), pack-reused 1477 (from 1)
# Receiving objects: 100% (2048/2048), 24.58 MiB | 40.02 MiB/s, done.
# Resolving deltas: 100% (1344/1344), done.
# xfolder='ComfyUI-KJNodes'
# /kaggle/working/ComfyUI/custom_nodes/ComfyUI-KJNodes
# Fetching origin
# Already up to date.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pointpats 2.5.0 requires shapely>=2, but you have shapely 1.8.5.post1 which is incompatible.
# spopt 0.6.1 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# ydata-profiling 4.9.0 requires scipy<1.14,>=1.4.1, but you have scipy 1.14.0 which is incompatible.
# Note: you may need to restart the kernel to use updated packages.
# DONE install  https://github.com/kijai/ComfyUI-KJNodes

# %%
# !apt -y install -qq aria2
# !aria2c --help
# Out:
# The following additional packages will be installed:
#   libaria2-0 libc-ares2 libssh2-1
# The following NEW packages will be installed:
#   aria2 libaria2-0 libc-ares2 libssh2-1
# 0 upgraded, 4 newly installed, 0 to remove and 39 not upgraded.
# Need to get 1622 kB of archives.
# After this operation, 5817 kB of additional disk space will be used.
#
# 78Selecting previously unselected package libc-ares2:amd64.
# (Reading database ... 123110 files and directories currently installed.)
# Preparing to unpack .../libc-ares2_1.18.1-1ubuntu0.22.04.3_amd64.deb ...
# 7Progress: [  0%] [..........................................................] 87Progress: [  6%] [###.......................................................] 8Unpacking libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.3) ...
# 7Progress: [ 12%] [######....................................................] 8Selecting previously unselected package libssh2-1:amd64.
# Preparing to unpack .../libssh2-1_1.10.0-3_amd64.deb ...
# 7Progress: [ 18%] [##########................................................] 8Unpacking libssh2-1:amd64 (1.10.0-3) ...
# 7Progress: [ 24%] [#############.............................................] 8Selecting previously unselected package libaria2-0:amd64.
# Preparing to unpack .../libaria2-0_1.36.0-1_amd64.deb ...
# 7Progress: [ 29%] [#################.........................................] 8Unpacking libaria2-0:amd64 (1.36.0-1) ...
# 7Progress: [ 35%] [####################......................................] 8Selecting previously unselected package aria2.
# Preparing to unpack .../aria2_1.36.0-1_amd64.deb ...
# 7Progress: [ 41%] [#######################...................................] 8Unpacking aria2 (1.36.0-1) ...
# 7Progress: [ 47%] [###########################...............................] 8Setting up libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.3) ...
# 7Progress: [ 53%] [##############################............................] 87Progress: [ 59%] [##################################........................] 8Setting up libssh2-1:amd64 (1.10.0-3) ...
# 7Progress: [ 65%] [#####################################.....................] 87Progress: [ 71%] [########################################..................] 8Setting up libaria2-0:amd64 (1.36.0-1) ...
# 7Progress: [ 76%] [############################################..............] 87Progress: [ 82%] [###############################################...........] 8Setting up aria2 (1.36.0-1) ...
# 7Progress: [ 88%] [###################################################.......] 87Progress: [ 94%] [######################################################....] 8Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
#
# 78

# %%
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/FLUX.1-dev/resolve/main/flux1-dev-fp8.safetensors -d /kaggle/working/ComfyUI/models/unet -o flux1-dev-fp8.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/FLUX.1-dev/resolve/main/ae.sft -d /kaggle/working/ComfyUI/models/vae -o ae.sft
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/FLUX.1-dev/resolve/main/clip_l.safetensors -d /kaggle/working/ComfyUI/models/clip -o clip_l.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/FLUX.1-dev/resolve/main/t5xxl_fp8_e4m3fn.safetensors -d /kaggle/working/ComfyUI/models/clip -o t5xxl_fp8_e4m3fn.safetensors
# Out:
# [#6c0b0e 11GiB/11GiB(99%) CN:12 DL:336MiB]
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 6c0b0e|OK  |   299MiB/s|/kaggle/working/ComfyUI/models/unet/flux1-dev-fp8.safetensors
#
# Status Legend:
# (OK):download completed.

# %%
# !wget -P ~ https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb -c --quiet
# !dpkg -i ~/cloudflared-linux-amd64.deb

# %% [raw]
# import subprocess
# import threading
# import time
# import socket
# import urllib.request
#
# def iframe_thread(port):
#   while True:
#       time.sleep(0.5)
#       sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
#       result = sock.connect_ex(('127.0.0.1', port))
#       if result == 0:
#         break
#       sock.close()
#   print("\nComfyUI finished loading, trying to launch cloudflared (if it gets stuck here cloudflared is having issues)\n")
#
#   p = subprocess.Popen(["cloudflared", "tunnel", "--url", "http://127.0.0.1:{}".format(port)], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
#   for line in p.stderr:
#     l = line.decode()
#     if "trycloudflare.com " in l:
#       print("This is the URL to access ComfyUI:", l[l.find("http"):], end='')
#     #print(l, end='')
#
#
# threading.Thread(target=iframe_thread, daemon=True, args=(8188,)).start()
#
# %cd /kaggle/working/ComfyUI/
# !python main.py --dont-print-server

# %%
get_ipython().system("npm install -g npm")
get_ipython().system("npm install -g localtunnel")

import subprocess
import threading
import time
import socket
import urllib.request

def iframe_thread(port):
  while True:
      time.sleep(0.5)
      sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
      result = sock.connect_ex(('127.0.0.1', port))
      if result == 0:
        break
      sock.close()
  print("\nComfyUI finished loading, trying to launch localtunnel (if it gets stuck here localtunnel is having issues)\n")

  print("The password/enpoint ip for localtunnel is:", urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip("\n"))
  p = subprocess.Popen(["lt", "--port", "{}".format(port)], stdout=subprocess.PIPE)
  for line in p.stdout:
    print(line.decode(), end='')


threading.Thread(target=iframe_thread, daemon=True, args=(8188,)).start()
# %cd /kaggle/working/ComfyUI/
# !python main.py --dont-print-server
